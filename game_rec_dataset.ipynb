# %% [markdown]
# <a href="https://colab.research.google.com/github/503N-project-RC/data-processing/blob/main/game_rec_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preparation

# %%
pip install steamspypi
# Out:
# Requirement already satisfied: steamspypi in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from steamspypi) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->steamspypi) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->steamspypi) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->steamspypi) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->steamspypi) (2025.1.31)

# %%
import steamspypi
import time
import csv
import json
import random
import numpy as np

# %% [markdown]
# # Part 1: Create games library

# %% [markdown]
# ## SteamSpy API

# %% [markdown]
# ### Fetch top 1000 most owned games

# %%
data_request = dict()
data_request['request'] = 'all'
data_request['page'] = '0'

all_games = steamspypi.download(data_request)

# %%
len(all_games)
# Out:
# 1000

# %% [markdown]
# ### Take subset

# %%
all_games = dict(list(all_games.items())[:450])
len(all_games)
# Out:
# 450

# %%
print(next(iter(all_games.items())))
# Out:
# ('570', {'appid': 570, 'name': 'Dota 2', 'developer': 'Valve', 'publisher': 'Valve', 'score_rank': '', 'positive': 2008594, 'negative': 454929, 'userscore': 0, 'owners': '200,000,000 .. 500,000,000', 'average_forever': 40480, 'average_2weeks': 1369, 'median_forever': 806, 'median_2weeks': 782, 'price': '0', 'initialprice': '0', 'discount': '0', 'ccu': 506892})

# %% [markdown]
# ### Drop "Wallpaper Engine" outlier game

# %%
for key, value in list(all_games.items()):
    if value['name'] == "Wallpaper Engine":
        del all_games[key]
        break

# %% [markdown]
# ### For each game in subset, fetch more details

# %%
all_games_detailed = {}

# %%
data_request = dict()
data_request['request'] = 'appdetails'

# %%
for game_id, game_data in all_games.items():
  data_request["appid"] = game_id
  data = steamspypi.download(data_request)

  tag_list = list(data.get("tags", {}).keys())

  all_games_detailed[str(game_id)] = {
      "name": data.get("name", ""),
      "rating_ratio": round(data.get("positive", 1) / data.get("negative", 1), 3),
      "price": data.get("price", "0"),
      "genre": [g.strip() for g in data.get("genre", "").split(",")],
      "tags": tag_list
  }

  time.sleep(1)

# %%
all_games_detailed
# Out:
# {'570': {'name': 'Dota 2',
#   'rating_ratio': 4.415,
#   'price': '0',
#   'genre': ['Action', 'Strategy', 'Free To Play'],
#   'tags': ['Free to Play',
#    'MOBA',
#    'Multiplayer',
#    'Strategy',
#    'e-sports',
#    'Team-Based',
#    'Competitive',
#    'Action',
#    'Online Co-Op',
#    'PvP',
#    'Difficult',
#    'Co-op',
#    'RTS',
#    'RPG',
#    'Tower Defense',
#    'Fantasy',
#    'Character Customization',
#    'Replay Value',
#    'Action RPG',
#    'Simulation']},
#  '730': {'name': 'Counter-Strike: Global Offensive',
#   'rating_ratio': 6.573,
#   'price': '0',
#   'genre': ['Action', 'Free To Play'],
#   'tags': ['FPS',
#    'Shooter',
#    'Multiplayer',
#    'Competitive',
#    'Action',
#    'Team-Based',
#    'e-sports',
#    'Tactical',
#    'First-Person',
#    'PvP',
#    'Online Co-Op',
#    'Co-op',
#    'Strategy',
#    'Military',
#    'War',
#    'Difficult',
#    'Trading',
#    'Realistic',
#    'Fast-Paced',
#    'Moddable']},
#  '578080': {'name': 'PUBG: BATTLEGROUNDS',
#   'rating_ratio': 1.457,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Massively Multiplayer', 'Free To Play'],
#   'tags': ['Survival',
#    'Shooter',
#    'Battle Royale',
#    'Multiplayer',
#    'FPS',
#    'PvP',
#    'Third-Person Shooter',
#    'Action',
#    'Online Co-Op',
#    'Tactical',
#    'Co-op',
#    'First-Person',
#    'Strategy',
#    'Early Access',
#    'Competitive',
#    'Third Person',
#    'Team-Based',
#    'Difficult',
#    'Simulation',
#    'Stealth']},
#  '1623730': {'name': 'Palworld',
#   'rating_ratio': 16.051,
#   'price': '2999',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG', 'Early Access'],
#   'tags': ['Open World',
#    'Survival',
#    'Multiplayer',
#    'Creature Collector',
#    'Open World Survival Craft',
#    'Crafting',
#    'Co-op',
#    'Adventure',
#    'Sandbox',
#    'Third-Person Shooter',
#    'Automation',
#    'Action',
#    'RPG',
#    'Early Access',
#    'Anime',
#    'PvE',
#    '3D',
#    'Indie',
#    'Looter Shooter',
#    'Hack and Slash']},
#  '1172470': {'name': 'Apex Legends',
#   'rating_ratio': 2.045,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Battle Royale',
#    'Multiplayer',
#    'FPS',
#    'Shooter',
#    'First-Person',
#    'PvP',
#    'Action',
#    'Hero Shooter',
#    'Team-Based',
#    'Tactical',
#    'Sci-fi',
#    'Survival',
#    'Loot',
#    'Co-op',
#    'Character Customization',
#    'Funny',
#    'Lore-Rich',
#    'Cyberpunk',
#    'Cinematic']},
#  '1063730': {'name': 'New World: Aeternum',
#   'rating_ratio': 2.188,
#   'price': '7999',
#   'genre': ['Action', 'Adventure', 'Massively Multiplayer', 'RPG'],
#   'tags': ['Open World',
#    'Massively Multiplayer',
#    'MMORPG',
#    'RPG',
#    'Adventure',
#    'Action',
#    'PvP',
#    'PvE',
#    'Multiplayer',
#    'Fantasy',
#    'Character Customization',
#    'Walking Simulator',
#    'Crafting',
#    'Third Person',
#    'Co-op',
#    'Open World Survival Craft',
#    'Sandbox',
#    'Violent',
#    'Sexual Content',
#    'Singleplayer']},
#  '2358720': {'name': 'Black Myth: Wukong',
#   'rating_ratio': 29.039,
#   'price': '5999',
#   'genre': ['Action', 'Adventure', 'RPG'],
#   'tags': ['Mythology',
#    'Action RPG',
#    'Action',
#    'Souls-like',
#    'RPG',
#    'Combat',
#    'Story Rich',
#    'Singleplayer',
#    'Action-Adventure',
#    'Drama',
#    'Dark Fantasy',
#    'Atmospheric',
#    'Adventure',
#    '3D',
#    'Fantasy',
#    'Hack and Slash',
#    'Third Person',
#    'Difficult',
#    'Music',
#    'Violent']},
#  '1938090': {'name': 'Call of Duty: Modern Warfare II',
#   'rating_ratio': 1.418,
#   'price': '4899',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Multiplayer',
#    'Shooter',
#    'Singleplayer',
#    'Action',
#    'Military',
#    'First-Person',
#    'War',
#    'Modern',
#    'Tactical',
#    'Violent',
#    'Co-op',
#    'Realistic',
#    'Story Rich',
#    'Atmospheric',
#    'Mature',
#    'Online Co-Op',
#    'Gore',
#    'Third-Person Shooter',
#    'Third Person']},
#  '271590': {'name': 'Grand Theft Auto V Legacy',
#   'rating_ratio': 6.9,
#   'price': '0',
#   'genre': ['Action', 'Adventure'],
#   'tags': ['Open World',
#    'Action',
#    'Multiplayer',
#    'Crime',
#    'Automobile Sim',
#    'Third Person',
#    'First-Person',
#    'Mature',
#    'Shooter',
#    'Adventure',
#    'Singleplayer',
#    'Third-Person Shooter',
#    'Racing',
#    'Co-op',
#    'Sandbox',
#    'Atmospheric',
#    'Funny',
#    'Great Soundtrack',
#    'Comedy',
#    'Moddable']},
#  '550': {'name': 'Left 4 Dead 2',
#   'rating_ratio': 39.607,
#   'price': '999',
#   'genre': ['Action'],
#   'tags': ['Zombies',
#    'Co-op',
#    'FPS',
#    'Multiplayer',
#    'Shooter',
#    'Online Co-Op',
#    'Action',
#    'Survival',
#    'Horror',
#    'First-Person',
#    'Gore',
#    'Team-Based',
#    'Moddable',
#    'Survival Horror',
#    'Post-apocalyptic',
#    'Singleplayer',
#    'Adventure',
#    'Local Co-Op',
#    'Replay Value',
#    'Tactical']},
#  '553850': {'name': 'HELLDIVERS 2',
#   'rating_ratio': 3.196,
#   'price': '3999',
#   'genre': ['Action'],
#   'tags': ['Online Co-Op',
#    'PvE',
#    'Third-Person Shooter',
#    'Multiplayer',
#    'Action',
#    'Shooter',
#    'Co-op',
#    'Sci-fi',
#    'Capitalism',
#    'Space',
#    'Extraction Shooter',
#    'Third Person',
#    'Comedy',
#    'Gore',
#    'Violent',
#    'Great Soundtrack',
#    'Difficult',
#    'Psychological Horror',
#    'Singleplayer',
#    'Open World']},
#  '1599340': {'name': 'Lost Ark',
#   'rating_ratio': 2.463,
#   'price': '0',
#   'genre': ['Action',
#    'Adventure',
#    'Massively Multiplayer',
#    'RPG',
#    'Free To Play'],
#   'tags': ['MMORPG',
#    'Free to Play',
#    'Action RPG',
#    'Multiplayer',
#    'Hack and Slash',
#    'RPG',
#    'Character Customization',
#    'Massively Multiplayer',
#    'Action',
#    'Sexual Content',
#    'Adventure',
#    'PvE',
#    'Fantasy',
#    'PvP',
#    'Isometric',
#    'Online Co-Op',
#    'Class-Based',
#    'Singleplayer',
#    'Violent',
#    'Gore']},
#  '304930': {'name': 'Unturned',
#   'rating_ratio': 10.407,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Casual', 'Indie', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Survival',
#    'Zombies',
#    'Multiplayer',
#    'Open World',
#    'Co-op',
#    'Sandbox',
#    'Crafting',
#    'Shooter',
#    'Adventure',
#    'Post-apocalyptic',
#    'First-Person',
#    'Singleplayer',
#    'Looter Shooter',
#    'FPS',
#    'Action',
#    'Massively Multiplayer',
#    'Indie',
#    'Atmospheric',
#    'Casual']},
#  '236390': {'name': 'War Thunder',
#   'rating_ratio': 1.75,
#   'price': '0',
#   'genre': ['Action', 'Massively Multiplayer', 'Simulation', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Simulation',
#    'Vehicular Combat',
#    'Combat',
#    'World War II',
#    'Flight',
#    'VR',
#    'War',
#    'Military',
#    'Tanks',
#    'Multiplayer',
#    'Naval Combat',
#    'Modern',
#    'Massively Multiplayer',
#    'Cold War',
#    'Realistic',
#    'Shooter',
#    'Action',
#    'Third Person',
#    'Third-Person Shooter']},
#  '1245620': {'name': 'ELDEN RING',
#   'rating_ratio': 12.998,
#   'price': '5999',
#   'genre': ['Action', 'RPG'],
#   'tags': ['Souls-like',
#    'Open World',
#    'Dark Fantasy',
#    'RPG',
#    'Difficult',
#    'Action RPG',
#    'Third Person',
#    'Multiplayer',
#    'Fantasy',
#    'Singleplayer',
#    'Online Co-Op',
#    'Action',
#    'Co-op',
#    'Atmospheric',
#    'PvP',
#    'Great Soundtrack',
#    'Violent',
#    '3D',
#    'Character Customization',
#    'Family Friendly']},
#  '105600': {'name': 'Terraria',
#   'rating_ratio': 38.869,
#   'price': '999',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG'],
#   'tags': ['Open World Survival Craft',
#    'Sandbox',
#    'Survival',
#    '2D',
#    'Multiplayer',
#    'Adventure',
#    'Pixel Graphics',
#    'Crafting',
#    'Building',
#    'Exploration',
#    'Co-op',
#    'Open World',
#    'Online Co-Op',
#    'Indie',
#    'Action',
#    'RPG',
#    'Singleplayer',
#    'Replay Value',
#    'Platformer',
#    'Atmospheric']},
#  '440': {'name': 'Team Fortress 2',
#   'rating_ratio': 8.616,
#   'price': '0',
#   'genre': ['Action', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Hero Shooter',
#    'Multiplayer',
#    'FPS',
#    'Shooter',
#    'Action',
#    'Class-Based',
#    'Team-Based',
#    'Funny',
#    'First-Person',
#    'Online Co-Op',
#    'Competitive',
#    'Cartoony',
#    'Trading',
#    'Co-op',
#    'Comedy',
#    'Robots',
#    'Tactical',
#    'Cartoon',
#    'Crafting']},
#  '291550': {'name': 'Brawlhalla',
#   'rating_ratio': 4.449,
#   'price': '0',
#   'genre': ['Action', 'Indie', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Multiplayer',
#    'Fighting',
#    '2D Fighter',
#    '2D Platformer',
#    'Casual',
#    'Local Multiplayer',
#    'Co-op',
#    'Platformer',
#    'Controller',
#    'Action',
#    'Online Co-Op',
#    'Local Co-Op',
#    'Fantasy',
#    '4 Player Local',
#    'Family Friendly',
#    'Cartoony',
#    'e-sports',
#    'Singleplayer',
#    'Indie']},
#  '1086940': {'name': "Baldur's Gate 3",
#   'rating_ratio': 30.665,
#   'price': '5999',
#   'genre': ['Adventure', 'RPG', 'Strategy'],
#   'tags': ['RPG',
#    'Character Customization',
#    'Choices Matter',
#    'Story Rich',
#    'Turn-Based Combat',
#    'Dungeons & Dragons',
#    'CRPG',
#    'Fantasy',
#    'Adventure',
#    'Romance',
#    'Sexual Content',
#    'Online Co-Op',
#    'Multiplayer',
#    'Strategy',
#    'Singleplayer',
#    'Co-op Campaign',
#    'Class-Based',
#    'Nudity',
#    'Dark Fantasy',
#    'Combat']},
#  '4000': {'name': "Garry's Mod",
#   'rating_ratio': 30.167,
#   'price': '999',
#   'genre': ['Casual', 'Indie', 'Simulation'],
#   'tags': ['Sandbox',
#    'Moddable',
#    'Multiplayer',
#    'Physics',
#    'Building',
#    'Casual',
#    'Funny',
#    'First-Person',
#    'Singleplayer',
#    'FPS',
#    'Simulation',
#    'Comedy',
#    'Shooter',
#    'Online Co-Op',
#    'Co-op',
#    'Action',
#    'Indie',
#    'PvP',
#    'Realistic',
#    'Exploration']},
#  '359550': {'name': "Tom Clancy's Rainbow Six Siege",
#   'rating_ratio': 5.248,
#   'price': '1999',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'PvP',
#    'e-sports',
#    'Multiplayer',
#    'Tactical',
#    'Shooter',
#    'Competitive',
#    'Online Co-Op',
#    'Action',
#    'Hero Shooter',
#    'Team-Based',
#    'Military',
#    'Strategy',
#    'First-Person',
#    'Co-op',
#    'War',
#    'Realistic',
#    'Destruction',
#    'Difficult',
#    '3D']},
#  '1085660': {'name': 'Destiny 2',
#   'rating_ratio': 3.926,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Open World',
#    'Multiplayer',
#    'Looter Shooter',
#    'MMORPG',
#    'FPS',
#    'Co-op',
#    'PvE',
#    'PvP',
#    'Shooter',
#    'Massively Multiplayer',
#    'Loot',
#    'First-Person',
#    'Sci-fi',
#    'Action',
#    'Adventure',
#    'Lore-Rich',
#    'Space',
#    'Competitive',
#    'Atmospheric']},
#  '252490': {'name': 'Rust',
#   'rating_ratio': 6.849,
#   'price': '3999',
#   'genre': ['Action', 'Adventure', 'Indie', 'Massively Multiplayer', 'RPG'],
#   'tags': ['Survival',
#    'Crafting',
#    'Multiplayer',
#    'Open World',
#    'Open World Survival Craft',
#    'Building',
#    'PvP',
#    'Sandbox',
#    'Adventure',
#    'First-Person',
#    'Action',
#    'Nudity',
#    'FPS',
#    'Shooter',
#    'Co-op',
#    'Online Co-Op',
#    'Indie',
#    'Post-apocalyptic',
#    'Early Access',
#    'Simulation']},
#  '346110': {'name': 'ARK: Survival Evolved',
#   'rating_ratio': 5.157,
#   'price': '1499',
#   'genre': ['Action', 'Adventure', 'Indie', 'Massively Multiplayer', 'RPG'],
#   'tags': ['Open World Survival Craft',
#    'Survival',
#    'Multiplayer',
#    'Open World',
#    'Dinosaurs',
#    'Crafting',
#    'Building',
#    'Adventure',
#    'Base-Building',
#    'Co-op',
#    'Action',
#    'First-Person',
#    'Sandbox',
#    'Massively Multiplayer',
#    'Singleplayer',
#    'Early Access',
#    'RPG',
#    'Dragons',
#    'Sci-fi',
#    'Indie']},
#  '892970': {'name': 'Valheim',
#   'rating_ratio': 16.792,
#   'price': '1999',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG', 'Early Access'],
#   'tags': ['Open World Survival Craft',
#    'Survival',
#    'Online Co-Op',
#    'Open World',
#    'Multiplayer',
#    'Building',
#    'Crafting',
#    'Base-Building',
#    'Exploration',
#    'Co-op',
#    'Adventure',
#    'Difficult',
#    'Mythology',
#    'Sandbox',
#    'PvE',
#    'Third Person',
#    'Singleplayer',
#    'Action',
#    'Early Access',
#    'Indie']},
#  '1091500': {'name': 'Cyberpunk 2077',
#   'rating_ratio': 5.293,
#   'price': '5999',
#   'genre': ['RPG'],
#   'tags': ['Cyberpunk',
#    'Open World',
#    'Nudity',
#    'RPG',
#    'Singleplayer',
#    'Sci-fi',
#    'FPS',
#    'Futuristic',
#    'Mature',
#    'Story Rich',
#    'First-Person',
#    'Atmospheric',
#    'Exploration',
#    'Action',
#    'Violent',
#    'Great Soundtrack',
#    'Action RPG',
#    'Adventure',
#    'Character Customization',
#    'Immersive Sim']},
#  '218620': {'name': 'PAYDAY 2',
#   'rating_ratio': 8.637,
#   'price': '999',
#   'genre': ['Action', 'RPG'],
#   'tags': ['Co-op',
#    'Action',
#    'FPS',
#    'Heist',
#    'Multiplayer',
#    'Looter Shooter',
#    'Online Co-Op',
#    'Stealth',
#    'Crime',
#    'Shooter',
#    'Team-Based',
#    'First-Person',
#    'Great Soundtrack',
#    'Gun Customization',
#    'Tactical',
#    'PvE',
#    'Strategy',
#    'Singleplayer',
#    'Funny',
#    'Simulation']},
#  '901583': {'name': 'Grand Theft Auto IV: Complete Edition',
#   'rating_ratio': 4.669,
#   'price': '0',
#   'genre': ['Action', 'Adventure'],
#   'tags': ['Open World',
#    'Action',
#    'Automobile Sim',
#    'Crime',
#    'Multiplayer',
#    'Third Person',
#    'Adventure',
#    'Singleplayer',
#    'Third-Person Shooter',
#    'Moddable',
#    'Sandbox',
#    'Shooter',
#    'Physics',
#    'Atmospheric',
#    'Classic',
#    'Funny',
#    'Dark Humor',
#    'Gore',
#    'Satire',
#    'Co-op']},
#  '238960': {'name': 'Path of Exile',
#   'rating_ratio': 8.339,
#   'price': '0',
#   'genre': ['Action',
#    'Adventure',
#    'Indie',
#    'Massively Multiplayer',
#    'RPG',
#    'Free To Play'],
#   'tags': ['Free to Play',
#    'Dark Fantasy',
#    'Action RPG',
#    'Hack and Slash',
#    'Loot',
#    'MMORPG',
#    'Multiplayer',
#    'Dungeon Crawler',
#    'Isometric',
#    'Character Customization',
#    'RPG',
#    'Inventory Management',
#    'Online Co-Op',
#    'Singleplayer',
#    'Action',
#    'PvP',
#    'Horror',
#    'Massively Multiplayer',
#    'Fantasy',
#    'Adventure']},
#  '242760': {'name': 'The Forest',
#   'rating_ratio': 21.428,
#   'price': '1999',
#   'genre': ['Action', 'Adventure', 'Indie', 'Simulation'],
#   'tags': ['Open World Survival Craft',
#    'Survival',
#    'Open World',
#    'Horror',
#    'Crafting',
#    'Adventure',
#    'Building',
#    'Survival Horror',
#    'First-Person',
#    'Action',
#    'Exploration',
#    'Sandbox',
#    'Singleplayer',
#    'Atmospheric',
#    'Simulation',
#    'Gore',
#    'Realistic',
#    'Indie',
#    'Zombies',
#    'Early Access']},
#  '322330': {'name': "Don't Starve Together",
#   'rating_ratio': 20.522,
#   'price': '1499',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG', 'Simulation', 'Strategy'],
#   'tags': ['Survival',
#    'Open World Survival Craft',
#    'Multiplayer',
#    'Co-op',
#    'Open World',
#    'Adventure',
#    'Crafting',
#    'Online Co-Op',
#    'Sandbox',
#    'Difficult',
#    'Indie',
#    '2D',
#    'Atmospheric',
#    'Funny',
#    'Survival Horror',
#    'Strategy',
#    'Horror',
#    'Singleplayer',
#    'Action',
#    'Rogue-like']},
#  '1203220': {'name': 'NARAKA: BLADEPOINT',
#   'rating_ratio': 2.344,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Massively Multiplayer'],
#   'tags': ['Battle Royale',
#    'Multiplayer',
#    'Martial Arts',
#    'PvP',
#    'Mature',
#    'Action',
#    'Female Protagonist',
#    'Character Customization',
#    'Massively Multiplayer',
#    'Survival',
#    'Fighting',
#    'Third Person',
#    'Swordplay',
#    'Hack and Slash',
#    'Anime',
#    'Parkour',
#    'Adventure',
#    'Free to Play',
#    'Violent',
#    'Gore']},
#  '899770': {'name': 'Last Epoch',
#   'rating_ratio': 3.407,
#   'price': '3499',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG'],
#   'tags': ['Action RPG',
#    'Loot',
#    'Hack and Slash',
#    'RPG',
#    'Multiplayer',
#    'Isometric',
#    'Action',
#    'Adventure',
#    'Co-op',
#    'Top-Down',
#    'Dungeon Crawler',
#    'Indie',
#    'Singleplayer',
#    'Fantasy',
#    'Gore',
#    'MMORPG',
#    'Character Customization',
#    'Magic',
#    'Violent',
#    'Early Access']},
#  '413150': {'name': 'Stardew Valley',
#   'rating_ratio': 62.901,
#   'price': '1499',
#   'genre': ['Indie', 'RPG', 'Simulation'],
#   'tags': ['Farming Sim',
#    'Pixel Graphics',
#    'Multiplayer',
#    'Life Sim',
#    'RPG',
#    'Relaxing',
#    'Agriculture',
#    'Simulation',
#    'Crafting',
#    'Sandbox',
#    'Indie',
#    'Building',
#    'Casual',
#    'Singleplayer',
#    'Open World',
#    '2D',
#    'Cute',
#    'Dating Sim',
#    'Great Soundtrack',
#    'Fishing']},
#  '340': {'name': 'Half-Life 2: Lost Coast',
#   'rating_ratio': 8.327,
#   'price': '1999',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Action',
#    'Singleplayer',
#    'First-Person',
#    'Sci-fi',
#    'Shooter',
#    'Short',
#    'Aliens',
#    'Dystopian ',
#    'Classic',
#    'Adventure',
#    'Atmospheric',
#    'Benchmark',
#    'Futuristic',
#    'Silent Protagonist',
#    'Free to Play',
#    'Post-apocalyptic',
#    'Story Rich',
#    'Multiplayer',
#    'Great Soundtrack']},
#  '381210': {'name': 'Dead by Daylight',
#   'rating_ratio': 3.771,
#   'price': '799',
#   'genre': ['Action'],
#   'tags': ['Horror',
#    'Multiplayer',
#    'Survival Horror',
#    'Online Co-Op',
#    'Co-op',
#    'Survival',
#    'Gore',
#    'Team-Based',
#    'Blood',
#    'Stealth',
#    'Third Person',
#    'Violent',
#    'First-Person',
#    'Psychological Horror',
#    'Action',
#    'Atmospheric',
#    'Strategy',
#    'Comedy',
#    'Mature',
#    'Difficult']},
#  '945360': {'name': 'Among Us',
#   'rating_ratio': 11.273,
#   'price': '499',
#   'genre': ['Casual'],
#   'tags': ['Multiplayer',
#    'Social Deduction',
#    'Online Co-Op',
#    'Space',
#    'Survival',
#    '2D',
#    'Funny',
#    'Psychological',
#    'Party Game',
#    'Co-op',
#    'Cartoony',
#    'Local Multiplayer',
#    'Casual',
#    'Action',
#    'PvP',
#    'Sci-fi',
#    'Colorful',
#    'Top-Down',
#    'Minigames',
#    'Aliens']},
#  '1097150': {'name': 'Fall Guys: Ultimate Knockout',
#   'rating_ratio': 4.347,
#   'price': '0',
#   'genre': ['Action', 'Casual', 'Indie', 'Massively Multiplayer', 'Sports'],
#   'tags': ['Multiplayer',
#    'Party Game',
#    'Battle Royale',
#    'Family Friendly',
#    'Massively Multiplayer',
#    'Platformer',
#    'Cute',
#    'Funny',
#    'PvP',
#    '3D Platformer',
#    'Controller',
#    'Casual',
#    'Colorful',
#    'Action',
#    'Online Co-Op',
#    'Co-op',
#    'Comedy',
#    'Physics',
#    'Indie',
#    'Difficult']},
#  '292030': {'name': 'The Witcher 3: Wild Hunt',
#   'rating_ratio': 24.78,
#   'price': '3999',
#   'genre': ['RPG'],
#   'tags': ['Open World',
#    'RPG',
#    'Story Rich',
#    'Atmospheric',
#    'Mature',
#    'Fantasy',
#    'Adventure',
#    'Singleplayer',
#    'Nudity',
#    'Choices Matter',
#    'Great Soundtrack',
#    'Third Person',
#    'Medieval',
#    'Action',
#    'Multiple Endings',
#    'Action RPG',
#    'Dark Fantasy',
#    'Magic',
#    'Dark',
#    'Sandbox']},
#  '227300': {'name': 'Euro Truck Simulator 2',
#   'rating_ratio': 36.899,
#   'price': '499',
#   'genre': ['Indie', 'Simulation'],
#   'tags': ['Driving',
#    'Transportation',
#    'Simulation',
#    'Open World',
#    'Automobile Sim',
#    'Realistic',
#    'Moddable',
#    'Relaxing',
#    'Exploration',
#    'Economy',
#    'Immersive Sim',
#    'Management',
#    'Atmospheric',
#    'Multiplayer',
#    'Controller',
#    'Family Friendly',
#    'Third Person',
#    'Adventure',
#    'Casual',
#    'Indie']},
#  '444090': {'name': 'Paladins',
#   'rating_ratio': 5.655,
#   'price': '0',
#   'genre': ['Action',
#    'Adventure',
#    'Massively Multiplayer',
#    'Strategy',
#    'Free To Play'],
#   'tags': ['Hero Shooter',
#    'Free to Play',
#    'Multiplayer',
#    'FPS',
#    'Shooter',
#    'Action',
#    'Team-Based',
#    'First-Person',
#    'PvP',
#    'MOBA',
#    'Online Co-Op',
#    'Fantasy',
#    'Controller',
#    'Strategy',
#    'Co-op',
#    'Character Customization',
#    'Massively Multiplayer',
#    'Colorful',
#    'Adventure',
#    'Funny']},
#  '552990': {'name': 'World of Warships',
#   'rating_ratio': 3.379,
#   'price': '0',
#   'genre': ['Action',
#    'Massively Multiplayer',
#    'Simulation',
#    'Strategy',
#    'Free To Play'],
#   'tags': ['Free to Play',
#    'Naval Combat',
#    'Co-op',
#    'Action',
#    'Tactical',
#    'Online Co-Op',
#    'Multiplayer',
#    'Massively Multiplayer',
#    'World War II',
#    'PvP',
#    'Naval',
#    'War',
#    'Simulation',
#    'Team-Based',
#    'Military',
#    'PvE',
#    'Shooter',
#    'Historical',
#    'Realistic',
#    'Third-Person Shooter']},
#  '438100': {'name': 'VRChat',
#   'rating_ratio': 3.092,
#   'price': '0',
#   'genre': ['Adventure',
#    'Casual',
#    'Massively Multiplayer',
#    'Simulation',
#    'Sports',
#    'Free To Play',
#    'Early Access'],
#   'tags': ['VR',
#    'Free to Play',
#    'Multiplayer',
#    'Anime',
#    'Memes',
#    'Funny',
#    'Massively Multiplayer',
#    'First-Person',
#    'Open World',
#    'Early Access',
#    'Simulation',
#    'Casual',
#    'Adventure',
#    'MMORPG',
#    'Comedy',
#    'Sandbox',
#    'Dating Sim',
#    'Action',
#    'Survival Horror',
#    'Atmospheric']},
#  '320': {'name': 'Half-Life 2: Deathmatch',
#   'rating_ratio': 9.791,
#   'price': '1999',
#   'genre': ['Action'],
#   'tags': ['Action',
#    'FPS',
#    'Multiplayer',
#    'Shooter',
#    'First-Person',
#    'Sci-fi',
#    'Physics',
#    'Competitive',
#    'Funny',
#    'Co-op',
#    'Old School',
#    'PvP',
#    'Arena Shooter',
#    'Moddable',
#    'Atmospheric',
#    'Adventure',
#    'Great Soundtrack',
#    'Singleplayer',
#    'Violent',
#    'Mod']},
#  '272060': {'name': 'Serena',
#   'rating_ratio': 3.354,
#   'price': '0',
#   'genre': ['Adventure', 'Indie'],
#   'tags': ['Horror',
#    'Free to Play',
#    'Indie',
#    'Point & Click',
#    'Psychological Horror',
#    'Adventure',
#    'Story Rich',
#    'Dark',
#    'Short',
#    'First-Person',
#    'Mystery',
#    'Atmospheric',
#    'Multiplayer',
#    'Singleplayer',
#    'Puzzle',
#    'Walking Simulator',
#    'Co-op',
#    'Hidden Object',
#    'Exploration',
#    'Romance']},
#  '739630': {'name': 'Phasmophobia',
#   'rating_ratio': 23.037,
#   'price': '1999',
#   'genre': ['Action', 'Indie', 'Early Access'],
#   'tags': ['Horror',
#    'Online Co-Op',
#    'Multiplayer',
#    'Psychological Horror',
#    'Co-op',
#    'VR',
#    'Supernatural',
#    'First-Person',
#    'Investigation',
#    'Dark',
#    'Demons',
#    'Detective',
#    'Mystery',
#    'Thriller',
#    '3D',
#    'Early Access',
#    'Indie',
#    'Action',
#    'Tactical',
#    'Singleplayer']},
#  '990080': {'name': 'Hogwarts Legacy',
#   'rating_ratio': 9.321,
#   'price': '5999',
#   'genre': ['Action', 'Adventure', 'RPG'],
#   'tags': ['Magic',
#    'Open World',
#    'Fantasy',
#    'Singleplayer',
#    'Adventure',
#    'RPG',
#    'Character Customization',
#    'Exploration',
#    'Story Rich',
#    'Third Person',
#    'Action-Adventure',
#    'Atmospheric',
#    'Action RPG',
#    'Action',
#    'Combat',
#    'Choices Matter',
#    'Puzzle',
#    'Great Soundtrack',
#    'Dark',
#    'Family Friendly']},
#  '620': {'name': 'Portal 2',
#   'rating_ratio': 75.398,
#   'price': '999',
#   'genre': ['Action', 'Adventure'],
#   'tags': ['Platformer',
#    'Puzzle',
#    'First-Person',
#    'Dark Humor',
#    'Story Rich',
#    'Puzzle-Platformer',
#    'Funny',
#    'Female Protagonist',
#    '3D Platformer',
#    'Action-Adventure',
#    'Action',
#    'FPS',
#    'Co-op',
#    'Physics',
#    'Sci-fi',
#    'Level Editor',
#    'Science',
#    'Comedy',
#    'Atmospheric',
#    'Adventure']},
#  '227940': {'name': 'Heroes & Generals',
#   'rating_ratio': 2.084,
#   'price': '0',
#   'genre': ['Action',
#    'Free To Play',
#    'Indie',
#    'Massively Multiplayer',
#    'Strategy'],
#   'tags': ['Free to Play',
#    'World War II',
#    'FPS',
#    'Multiplayer',
#    'War',
#    'Shooter',
#    'Action',
#    'First-Person',
#    'Massively Multiplayer',
#    'Strategy',
#    'Tactical',
#    'Co-op',
#    'Historical',
#    'Open World',
#    'Simulation',
#    'Atmospheric',
#    'Adventure',
#    'Indie',
#    'Early Access',
#    'RTS']},
#  '70': {'name': 'Half-Life',
#   'rating_ratio': 27.966,
#   'price': '999',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Classic',
#    "1990's",
#    'Singleplayer',
#    'Multiplayer',
#    'Sci-fi',
#    'Shooter',
#    'Action',
#    'First-Person',
#    'Aliens',
#    'Story Rich',
#    'Silent Protagonist',
#    'Atmospheric',
#    'Gore',
#    'Retro',
#    'Moddable',
#    'Adventure',
#    'Action-Adventure',
#    'Difficult',
#    'PvP']},
#  '252950': {'name': 'Rocket League',
#   'rating_ratio': 6.947,
#   'price': '0',
#   'genre': ['Action', 'Indie', 'Racing', 'Sports'],
#   'tags': ['Multiplayer',
#    'Football (Soccer)',
#    'Competitive',
#    'Sports',
#    'Racing',
#    'Team-Based',
#    'Online Co-Op',
#    'Football (American)',
#    'Fast-Paced',
#    'Co-op',
#    'Action',
#    'Funny',
#    'Great Soundtrack',
#    'Local Multiplayer',
#    'Split Screen',
#    'Local Co-Op',
#    'Singleplayer',
#    '4 Player Local',
#    'Casual',
#    'Indie']},
#  '1966720': {'name': 'Lethal Company',
#   'rating_ratio': 35.213,
#   'price': '999',
#   'genre': ['Action', 'Adventure', 'Indie', 'Early Access'],
#   'tags': ['Online Co-Op',
#    'Horror',
#    'First-Person',
#    'Co-op',
#    'Survival Horror',
#    'Exploration',
#    'Funny',
#    'Psychological Horror',
#    'Sci-fi',
#    'PvE',
#    'Atmospheric',
#    'Procedural Generation',
#    'Aliens',
#    'Time Management',
#    'Adventure',
#    'Dungeon Crawler',
#    'Action',
#    'Early Access',
#    'Action-Adventure',
#    'Perma Death']},
#  '1517290': {'name': 'Battlefield 2042',
#   'rating_ratio': 0.874,
#   'price': '5999',
#   'genre': ['Action', 'Adventure', 'Casual'],
#   'tags': ['FPS',
#    'Multiplayer',
#    'Shooter',
#    'Military',
#    'War',
#    'Singleplayer',
#    'Action',
#    'First-Person',
#    'Combat',
#    'Team-Based',
#    'PvP',
#    'Futuristic',
#    'Vehicular Combat',
#    'Modern',
#    'Destruction',
#    'Physics',
#    'Cinematic',
#    'Adventure',
#    'Hero Shooter',
#    'Casual']},
#  '1240440': {'name': 'Halo Infinite',
#   'rating_ratio': 2.313,
#   'price': '0',
#   'genre': ['Action', 'Free To Play'],
#   'tags': ['Free to Play',
#    'FPS',
#    'Multiplayer',
#    'Singleplayer',
#    'Shooter',
#    'Action',
#    'First-Person',
#    'Open World',
#    'Sci-fi',
#    'Co-op',
#    'PvP',
#    'Competitive',
#    'Story Rich',
#    'Space',
#    'Adventure',
#    'Aliens',
#    'Lore-Rich',
#    'Cinematic',
#    'Atmospheric',
#    'Soundtrack']},
#  '582010': {'name': 'Monster Hunter: World',
#   'rating_ratio': 7.311,
#   'price': '2999',
#   'genre': ['Action'],
#   'tags': ['Co-op',
#    'Multiplayer',
#    'Action',
#    'Open World',
#    'RPG',
#    'Character Customization',
#    'Third Person',
#    'Adventure',
#    'Fantasy',
#    'Action RPG',
#    'Difficult',
#    'Singleplayer',
#    'Exploration',
#    'Great Soundtrack',
#    'Replay Value',
#    'Atmospheric',
#    'Hack and Slash',
#    'JRPG',
#    'MMORPG',
#    'Souls-like']},
#  '240': {'name': 'Counter-Strike: Source',
#   'rating_ratio': 25.789,
#   'price': '999',
#   'genre': ['Action'],
#   'tags': ['Shooter',
#    'FPS',
#    'Action',
#    'Multiplayer',
#    'Team-Based',
#    'First-Person',
#    'Competitive',
#    'Tactical',
#    'PvP',
#    'e-sports',
#    'Military',
#    'War',
#    'Strategy',
#    'Moddable',
#    'Singleplayer',
#    'Difficult',
#    'Atmospheric',
#    'Survival',
#    'Simulation',
#    'Sandbox']},
#  '108600': {'name': 'Project Zomboid',
#   'rating_ratio': 16.171,
#   'price': '1999',
#   'genre': ['Indie', 'RPG', 'Simulation', 'Early Access'],
#   'tags': ['Survival',
#    'Zombies',
#    'Open World',
#    'Multiplayer',
#    'Open World Survival Craft',
#    'Sandbox',
#    'Post-apocalyptic',
#    'Co-op',
#    'Crafting',
#    'Building',
#    'Indie',
#    'Simulation',
#    'RPG',
#    'Survival Horror',
#    'Realistic',
#    'Isometric',
#    'Singleplayer',
#    '2D',
#    'Adventure',
#    'Early Access']},
#  '386360': {'name': 'SMITE',
#   'rating_ratio': 3.716,
#   'price': '0',
#   'genre': ['Action',
#    'Adventure',
#    'Casual',
#    'Massively Multiplayer',
#    'RPG',
#    'Strategy',
#    'Free To Play'],
#   'tags': ['Free to Play',
#    'MOBA',
#    'Multiplayer',
#    'Action',
#    'Third Person',
#    'Mythology',
#    'Strategy',
#    'MMORPG',
#    'Team-Based',
#    'Nostalgia',
#    'Competitive',
#    'Anime',
#    'PvP',
#    'Co-op',
#    'e-sports',
#    'Massively Multiplayer',
#    'RPG',
#    'Adventure',
#    'Casual',
#    'Strategy RPG']},
#  '10': {'name': 'Counter-Strike',
#   'rating_ratio': 37.981,
#   'price': '999',
#   'genre': ['Action'],
#   'tags': ['Action',
#    'FPS',
#    'Multiplayer',
#    'Shooter',
#    'Classic',
#    'Team-Based',
#    'First-Person',
#    'Competitive',
#    'Tactical',
#    "1990's",
#    'e-sports',
#    'PvP',
#    'Old School',
#    'Military',
#    'Strategy',
#    'Survival',
#    'Score Attack',
#    '1980s',
#    'Assassin',
#    'Nostalgia']},
#  '648800': {'name': 'Raft',
#   'rating_ratio': 14.014,
#   'price': '1999',
#   'genre': ['Adventure', 'Indie', 'Simulation'],
#   'tags': ['Survival',
#    'Multiplayer',
#    'Open World Survival Craft',
#    'Co-op',
#    'Crafting',
#    'Open World',
#    'Building',
#    'Base-Building',
#    'Online Co-Op',
#    'Adventure',
#    'Sandbox',
#    'First-Person',
#    'Singleplayer',
#    'Underwater',
#    'Simulation',
#    'Early Access',
#    'Action',
#    'Indie',
#    'Strategy',
#    'Massively Multiplayer']},
#  '1468810': {'name': '鬼谷八荒 Tale of Immortal',
#   'rating_ratio': 1.136,
#   'price': '1999',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG', 'Simulation'],
#   'tags': ['Management',
#    'Singleplayer',
#    'Simulation',
#    'Mythology',
#    'Sandbox',
#    'Tactical RPG',
#    'RPG',
#    'Choose Your Own Adventure',
#    'Dating Sim',
#    'Action',
#    'Adventure',
#    'Exploration',
#    'Story Rich',
#    '2D',
#    'Hack and Slash',
#    'Action RPG',
#    'Procedural Generation',
#    'Hand-drawn',
#    'Action-Adventure',
#    'Strategy RPG']},
#  '444200': {'name': 'World of Tanks Blitz',
#   'rating_ratio': 3.688,
#   'price': '0',
#   'genre': ['Action',
#    'Massively Multiplayer',
#    'Simulation',
#    'Strategy',
#    'Free To Play'],
#   'tags': ['Tanks',
#    'Free to Play',
#    'Shooter',
#    'Action',
#    'FPS',
#    'Strategy',
#    'Multiplayer',
#    'Massively Multiplayer',
#    'PvP',
#    'Real Time Tactics',
#    'World War II',
#    'Team-Based',
#    'War',
#    'Online Co-Op',
#    'Competitive',
#    'Military',
#    'Singleplayer',
#    'Realistic',
#    '3D Platformer',
#    'Vehicular Combat']},
#  '755790': {'name': 'Ring of Elysium',
#   'rating_ratio': 2.913,
#   'price': '0',
#   'genre': ['Action', 'Free To Play', 'Massively Multiplayer'],
#   'tags': ['Free to Play',
#    'Battle Royale',
#    'Shooter',
#    'Multiplayer',
#    'Survival',
#    'FPS',
#    'Action',
#    'Massively Multiplayer',
#    'Third-Person Shooter',
#    'Early Access',
#    'Singleplayer',
#    'Open World',
#    'PvP',
#    'Co-op',
#    'Tactical',
#    '3D',
#    'Violent',
#    'Gore',
#    'MOBA',
#    'First-Person']},
#  '1174180': {'name': 'Red Dead Redemption 2',
#   'rating_ratio': 11.706,
#   'price': '1499',
#   'genre': ['Action', 'Adventure'],
#   'tags': ['Open World',
#    'Story Rich',
#    'Western',
#    'Adventure',
#    'Multiplayer',
#    'Action',
#    'Realistic',
#    'Singleplayer',
#    'Shooter',
#    'Atmospheric',
#    'Horses',
#    'Beautiful',
#    'Mature',
#    'Third-Person Shooter',
#    'Great Soundtrack',
#    'Third Person',
#    'Gore',
#    'Sandbox',
#    'First-Person',
#    'FPS']},
#  '250900': {'name': 'The Binding of Isaac: Rebirth',
#   'rating_ratio': 36.747,
#   'price': '1499',
#   'genre': ['Action'],
#   'tags': ['Action Roguelike',
#    'Rogue-like',
#    'Indie',
#    'Replay Value',
#    'Difficult',
#    'Pixel Graphics',
#    'Dungeon Crawler',
#    'Great Soundtrack',
#    'Singleplayer',
#    'Dark',
#    '2D',
#    'Local Co-Op',
#    'Remake',
#    'Gore',
#    'Procedural Generation',
#    'Rogue-lite',
#    'Atmospheric',
#    'Co-op',
#    'Action',
#    'Horror']},
#  '550650': {'name': 'Black Squad',
#   'rating_ratio': 3.158,
#   'price': '0',
#   'genre': ['Action', 'Free To Play'],
#   'tags': ['Free to Play',
#    'FPS',
#    'Shooter',
#    'Multiplayer',
#    'Action',
#    'Early Access',
#    'First-Person',
#    'Military',
#    'Singleplayer',
#    'PvP',
#    'Co-op',
#    'War',
#    'Tactical',
#    'Massively Multiplayer',
#    'Team-Based',
#    'Violent',
#    'Open World',
#    'Strategy',
#    'Gore',
#    'Adventure']},
#  '367520': {'name': 'Hollow Knight',
#   'rating_ratio': 32.812,
#   'price': '1499',
#   'genre': ['Action', 'Adventure', 'Indie'],
#   'tags': ['Metroidvania',
#    'Souls-like',
#    'Platformer',
#    'Great Soundtrack',
#    '2D',
#    'Difficult',
#    'Indie',
#    'Singleplayer',
#    'Atmospheric',
#    'Exploration',
#    'Adventure',
#    'Story Rich',
#    'Hand-drawn',
#    'Multiple Endings',
#    'Action',
#    'Dark Fantasy',
#    'Open World',
#    'Cute',
#    'Controller',
#    'Side Scroller']},
#  '301520': {'name': 'Robocraft',
#   'rating_ratio': 2.708,
#   'price': '0',
#   'genre': ['Action',
#    'Indie',
#    'Massively Multiplayer',
#    'RPG',
#    'Simulation',
#    'Free To Play'],
#   'tags': ['Free to Play',
#    'Robots',
#    'Building',
#    'Multiplayer',
#    'Action',
#    'Shooter',
#    'PvP',
#    'Massively Multiplayer',
#    'Sandbox',
#    'Crafting',
#    'Third-Person Shooter',
#    'Sci-fi',
#    'Strategy',
#    'Simulation',
#    'Early Access',
#    'Indie',
#    'Open World',
#    'Funny',
#    'Adventure',
#    'RPG']},
#  '239140': {'name': 'Dying Light',
#   'rating_ratio': 19.853,
#   'price': '1999',
#   'genre': ['Action', 'RPG'],
#   'tags': ['Zombies',
#    'Survival Horror',
#    'Horror',
#    'Online Co-Op',
#    'Open World',
#    'Parkour',
#    'First-Person',
#    'Survival',
#    'Open World Survival Craft',
#    'Gore',
#    'FPS',
#    'Action',
#    'PvE',
#    'Stealth',
#    'PvP',
#    'Multiplayer',
#    'Post-apocalyptic',
#    'Story Rich',
#    'Action RPG',
#    'Hack and Slash']},
#  '477160': {'name': 'Human Fall Flat',
#   'rating_ratio': 17.805,
#   'price': '1999',
#   'genre': ['Adventure', 'Casual', 'Indie', 'Simulation'],
#   'tags': ['Co-op',
#    'Funny',
#    'Puzzle',
#    'Adventure',
#    'Physics',
#    'Sandbox',
#    'Multiplayer',
#    'Puzzle-Platformer',
#    'Action',
#    'Open World',
#    'Local Co-Op',
#    'Indie',
#    'Local Multiplayer',
#    'Comedy',
#    'Parkour',
#    'Casual',
#    'Split Screen',
#    '3D Platformer',
#    'Singleplayer',
#    'Simulation']},
#  '251570': {'name': '7 Days to Die',
#   'rating_ratio': 7.778,
#   'price': '4499',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG', 'Simulation', 'Strategy'],
#   'tags': ['Survival',
#    'Zombies',
#    'Multiplayer',
#    'Open World',
#    'Open World Survival Craft',
#    'Base-Building',
#    'Voxel',
#    'Post-apocalyptic',
#    'Online Co-Op',
#    'Building',
#    'Exploration',
#    'Sandbox',
#    'FPS',
#    'Simulation',
#    'Character Customization',
#    'Tower Defense',
#    'Action',
#    'Strategy',
#    'Horror',
#    'Procedural Generation']},
#  '814380': {'name': 'Sekiro: Shadows Die Twice - GOTY Edition',
#   'rating_ratio': 20.2,
#   'price': '5999',
#   'genre': ['Action', 'Adventure'],
#   'tags': ['Souls-like',
#    'Difficult',
#    'Action',
#    'Singleplayer',
#    'Ninja',
#    'Stealth',
#    'Adventure',
#    'Third Person',
#    'Open World',
#    'Story Rich',
#    'Violent',
#    'Atmospheric',
#    'Assassin',
#    'Dark Fantasy',
#    'Hack and Slash',
#    'RPG',
#    'Gore',
#    'Great Soundtrack',
#    'Rhythm',
#    'Dark']},
#  '1222670': {'name': 'The Sims 4',
#   'rating_ratio': 6.882,
#   'price': '0',
#   'genre': ['Adventure', 'Casual', 'Simulation', 'Free To Play'],
#   'tags': ['Life Sim',
#    'Character Customization',
#    'Free to Play',
#    'Building',
#    'Romance',
#    'Simulation',
#    'Sandbox',
#    'Singleplayer',
#    'Dating Sim',
#    'Relaxing',
#    'Casual',
#    'Realistic',
#    'Funny',
#    'Family Friendly',
#    'Fantasy',
#    'Cute',
#    'Immersive Sim',
#    'Adventure',
#    'Cartoony',
#    'Nudity']},
#  '417910': {'name': 'Street Warriors Online',
#   'rating_ratio': 1.352,
#   'price': '199',
#   'genre': ['Action', 'Massively Multiplayer', 'Simulation', 'Sports'],
#   'tags': ['Fighting',
#    'Action',
#    'Multiplayer',
#    'Sports',
#    'Violent',
#    'Massively Multiplayer',
#    'Simulation',
#    'Open World',
#    'PvP',
#    'Free to Play',
#    'Early Access',
#    'Co-op',
#    'Indie',
#    'Funny',
#    'Character Customization',
#    'Singleplayer']},
#  '433850': {'name': 'Z1 Battle Royale',
#   'rating_ratio': 1.259,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Free To Play', 'Massively Multiplayer'],
#   'tags': ['Survival',
#    'Massively Multiplayer',
#    'Multiplayer',
#    'Open World',
#    'Battle Royale',
#    'PvP',
#    'FPS',
#    'Action',
#    'Shooter',
#    'Free to Play',
#    'Third-Person Shooter',
#    'Zombies',
#    'Co-op',
#    'Early Access',
#    'Online Co-Op',
#    'Adventure',
#    'First-Person',
#    'Violent',
#    'Gore',
#    'Walking Simulator']},
#  '594650': {'name': 'Hunt: Showdown 1896',
#   'rating_ratio': 2.716,
#   'price': '1499',
#   'genre': ['Action'],
#   'tags': ['Open World',
#    'Extraction Shooter',
#    'Multiplayer',
#    'Atmospheric',
#    'Tactical',
#    'FPS',
#    'Perma Death',
#    'Western',
#    'Shooter',
#    'PvP',
#    'Horror',
#    'Online Co-Op',
#    'Survival Horror',
#    'Co-op',
#    'Difficult',
#    'Battle Royale',
#    'Team-Based',
#    'Action',
#    'Gore',
#    'Zombies']},
#  '220': {'name': 'Half-Life 2',
#   'rating_ratio': 40.703,
#   'price': '999',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Action',
#    'Sci-fi',
#    'Classic',
#    'Singleplayer',
#    'Story Rich',
#    'Shooter',
#    'First-Person',
#    'Adventure',
#    'Dystopian ',
#    'Atmospheric',
#    'Zombies',
#    'Silent Protagonist',
#    'Physics',
#    'Aliens',
#    'Great Soundtrack',
#    'Horror',
#    'Multiplayer',
#    'Puzzle',
#    'Moddable']},
#  '230410': {'name': 'Warframe',
#   'rating_ratio': 6.763,
#   'price': '0',
#   'genre': ['Action', 'RPG', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Action RPG',
#    'Looter Shooter',
#    'Third-Person Shooter',
#    'Action',
#    'RPG',
#    'Third Person',
#    'Character Customization',
#    'Massively Multiplayer',
#    'Online Co-Op',
#    'Co-op',
#    'PvE',
#    'Singleplayer',
#    'Sci-fi',
#    'Space',
#    'Shooter',
#    'Lore-Rich',
#    'Hack and Slash',
#    'Parkour',
#    'Ninja']},
#  '219990': {'name': 'Grim Dawn',
#   'rating_ratio': 14.986,
#   'price': '2499',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG'],
#   'tags': ['Action RPG',
#    'Hack and Slash',
#    'Loot',
#    'Isometric',
#    'Dark Fantasy',
#    'RPG',
#    'Dungeon Crawler',
#    'Singleplayer',
#    'Co-op',
#    'Character Customization',
#    'Dark',
#    'Multiplayer',
#    'Adventure',
#    'Fantasy',
#    'Action',
#    'Atmospheric',
#    'Post-apocalyptic',
#    'Crafting',
#    'Moddable',
#    'Choices Matter']},
#  '261550': {'name': 'Mount & Blade II: Bannerlord',
#   'rating_ratio': 7.22,
#   'price': '4999',
#   'genre': ['Action', 'Indie', 'RPG', 'Simulation', 'Strategy'],
#   'tags': ['Medieval',
#    'Strategy',
#    'Open World',
#    'RPG',
#    'War',
#    'Sandbox',
#    'Multiplayer',
#    'Singleplayer',
#    'Action',
#    'Character Customization',
#    'Simulation',
#    'Moddable',
#    'Adventure',
#    'Horses',
#    'Realistic',
#    'Third Person',
#    'Historical',
#    'First-Person',
#    'Great Soundtrack',
#    'Early Access']},
#  '8930': {'name': "Sid Meier's Civilization V",
#   'rating_ratio': 22.915,
#   'price': '2999',
#   'genre': ['Strategy'],
#   'tags': ['Turn-Based Strategy',
#    'Strategy',
#    'Turn-Based',
#    'Multiplayer',
#    'Historical',
#    '4X',
#    'Addictive',
#    'Singleplayer',
#    'Hex Grid',
#    'Grand Strategy',
#    'Replay Value',
#    'Co-op',
#    'Economy',
#    'Tactical',
#    'Diplomacy',
#    'Moddable',
#    'Simulation',
#    'Classic',
#    'Great Soundtrack',
#    'Touch-Friendly']},
#  '304050': {'name': 'Trove',
#   'rating_ratio': 4.069,
#   'price': '0',
#   'genre': ['Action',
#    'Adventure',
#    'Casual',
#    'Massively Multiplayer',
#    'RPG',
#    'Free To Play'],
#   'tags': ['Free to Play',
#    'Open World',
#    'Sandbox',
#    'Pixel Graphics',
#    'Fantasy',
#    'MMORPG',
#    'Voxel',
#    'Replay Value',
#    'Family Friendly',
#    'Crafting',
#    'Procedural Generation',
#    'Multiplayer',
#    'Building',
#    'RPG',
#    'Adventure',
#    'Dungeon Crawler',
#    'Massively Multiplayer',
#    'Nostalgia',
#    'Action',
#    'Colorful']},
#  '107410': {'name': 'Arma 3',
#   'rating_ratio': 9.443,
#   'price': '2999',
#   'genre': ['Action', 'Simulation', 'Strategy'],
#   'tags': ['Military',
#    'Action',
#    'Multiplayer',
#    'Shooter',
#    'Simulation',
#    'Realistic',
#    'First-Person',
#    'Open World',
#    'Tactical',
#    'FPS',
#    'War',
#    'Co-op',
#    'Strategy',
#    'Sandbox',
#    'Singleplayer',
#    'Moddable',
#    'Combat',
#    'Online Co-Op',
#    'Team-Based',
#    'Third-Person Shooter']},
#  '377160': {'name': 'Fallout 4',
#   'rating_ratio': 4.897,
#   'price': '1999',
#   'genre': ['RPG'],
#   'tags': ['Open World',
#    'Post-apocalyptic',
#    'Singleplayer',
#    'Exploration',
#    'RPG',
#    'Adventure',
#    'Atmospheric',
#    'Shooter',
#    'First-Person',
#    'Story Rich',
#    'Action',
#    'Sci-fi',
#    'FPS',
#    'Action RPG',
#    'Sandbox',
#    'Great Soundtrack',
#    'Survival',
#    'Third Person',
#    'Third-Person Shooter',
#    'Character Customization']},
#  '532210': {'name': 'Life is Strange 2',
#   'rating_ratio': 6.246,
#   'price': '3196',
#   'genre': ['Adventure'],
#   'tags': ['Choices Matter',
#    'Story Rich',
#    'Adventure',
#    'Singleplayer',
#    'Great Soundtrack',
#    'Atmospheric',
#    'Episodic',
#    'Drama',
#    'Sexual Content',
#    'Choose Your Own Adventure',
#    'LGBTQ+',
#    'Point & Click',
#    'Third Person',
#    'Walking Simulator',
#    'Mystery',
#    'Nudity',
#    'Puzzle',
#    'Comedy',
#    'Funny',
#    'Classic']},
#  '255710': {'name': 'Cities: Skylines',
#   'rating_ratio': 13.208,
#   'price': '2999',
#   'genre': ['Simulation', 'Strategy'],
#   'tags': ['City Builder',
#    'Simulation',
#    'Building',
#    'Management',
#    'Strategy',
#    'Sandbox',
#    'Singleplayer',
#    'Moddable',
#    'Economy',
#    'Resource Management',
#    'Mod',
#    'Realistic',
#    'Replay Value',
#    'Casual',
#    'Modern',
#    'Real-Time with Pause',
#    'Family Friendly',
#    'Great Soundtrack',
#    'Funny',
#    'Action']},
#  '1326470': {'name': 'Sons Of The Forest',
#   'rating_ratio': 7.104,
#   'price': '2999',
#   'genre': ['Action', 'Adventure', 'Indie', 'Simulation'],
#   'tags': ['Survival',
#    'Open World',
#    'Multiplayer',
#    'Co-op',
#    'Survival Horror',
#    'Base-Building',
#    'Horror',
#    'Crafting',
#    'First-Person',
#    'Building',
#    'Exploration',
#    'Adventure',
#    'Singleplayer',
#    'Atmospheric',
#    'Sandbox',
#    'Action-Adventure',
#    'Action',
#    'Simulation',
#    'Immersive Sim',
#    'Early Access']},
#  '289070': {'name': 'Sid Meier’s Civilization VI',
#   'rating_ratio': 6.598,
#   'price': '599',
#   'genre': ['Strategy'],
#   'tags': ['Strategy',
#    'Turn-Based Strategy',
#    'Multiplayer',
#    'Historical',
#    'Grand Strategy',
#    'Singleplayer',
#    'Turn-Based',
#    '4X',
#    'War',
#    'City Builder',
#    'Simulation',
#    'Tactical',
#    'Management',
#    'Building',
#    'Great Soundtrack',
#    'Online Co-Op',
#    'Moddable',
#    'Co-op',
#    'Hex Grid',
#    'Atmospheric']},
#  '526870': {'name': 'Satisfactory',
#   'rating_ratio': 33.72,
#   'price': '3999',
#   'genre': ['Adventure', 'Indie', 'Simulation', 'Strategy'],
#   'tags': ['Base-Building',
#    'Automation',
#    'Open World',
#    'Multiplayer',
#    'Crafting',
#    'Co-op',
#    'Resource Management',
#    'Building',
#    'Sandbox',
#    'Exploration',
#    'Adventure',
#    'Open World Survival Craft',
#    'Survival',
#    'Simulation',
#    'First-Person',
#    'Strategy',
#    'Sci-fi',
#    'Singleplayer',
#    'Early Access',
#    'Indie']},
#  '1238810': {'name': 'Battlefield V',
#   'rating_ratio': 2.436,
#   'price': '4999',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Multiplayer',
#    'Singleplayer',
#    'World War II',
#    'Shooter',
#    'War',
#    'Military',
#    'First-Person',
#    'Massively Multiplayer',
#    'PvP',
#    'Combat',
#    'Open World',
#    'Action',
#    'Historical',
#    'Destruction',
#    'Battle Royale',
#    'Atmospheric',
#    'Violent',
#    'Sexual Content',
#    'Female Protagonist']},
#  '60': {'name': 'Ricochet',
#   'rating_ratio': 4.772,
#   'price': '499',
#   'genre': ['Action'],
#   'tags': ['Action',
#    'FPS',
#    'Multiplayer',
#    'Classic',
#    'First-Person',
#    'Sci-fi',
#    'Shooter',
#    'Space',
#    'Cyberpunk',
#    '3D',
#    'Psychological Horror',
#    'Retro',
#    'Memes',
#    'Platformer',
#    'Old School',
#    'Conspiracy',
#    'Cult Classic',
#    'Competitive',
#    'Sports',
#    'Great Soundtrack']},
#  '221100': {'name': 'DayZ',
#   'rating_ratio': 3.27,
#   'price': '4999',
#   'genre': ['Action', 'Adventure', 'Massively Multiplayer'],
#   'tags': ['Survival',
#    'Open World',
#    'Online Co-Op',
#    'Zombies',
#    'Multiplayer',
#    'Post-apocalyptic',
#    'Shooter',
#    'PvP',
#    'Massively Multiplayer',
#    'Action',
#    'FPS',
#    'Horror',
#    'Sandbox',
#    'Co-op',
#    'Adventure',
#    'Survival Horror',
#    'First-Person',
#    'Simulation',
#    'Atmospheric',
#    'Choose Your Own Adventure']},
#  '1089350': {'name': 'NBA 2K20',
#   'rating_ratio': 0.995,
#   'price': '0',
#   'genre': ['Simulation', 'Sports'],
#   'tags': ['Basketball',
#    'Sports',
#    'Simulation',
#    'Multiplayer',
#    'Singleplayer',
#    'Capitalism',
#    'Casual',
#    'Loot',
#    'Local Multiplayer',
#    'Massively Multiplayer',
#    'Character Customization',
#    'Controller',
#    'Realistic']},
#  '204360': {'name': 'Castle Crashers',
#   'rating_ratio': 24.868,
#   'price': '1499',
#   'genre': ['Action', 'Adventure', 'Casual', 'Indie', 'RPG'],
#   'tags': ['2D',
#    'Online Co-Op',
#    'Co-op',
#    "Beat 'em up",
#    'Hack and Slash',
#    'Funny',
#    'Adventure',
#    '4 Player Local',
#    'Local Co-Op',
#    'Multiplayer',
#    'Local Multiplayer',
#    'Action',
#    'Singleplayer',
#    'Medieval',
#    'Cartoony',
#    'Cute',
#    'Comedy',
#    'RPG',
#    'Arcade',
#    'Casual']},
#  '632360': {'name': 'Risk of Rain 2',
#   'rating_ratio': 14.292,
#   'price': '824',
#   'genre': ['Action', 'Indie'],
#   'tags': ['Third-Person Shooter',
#    'Action Roguelike',
#    'Multiplayer',
#    'Co-op',
#    'Action',
#    'Rogue-lite',
#    'Rogue-like',
#    'Looter Shooter',
#    'Loot',
#    'Online Co-Op',
#    'Shooter',
#    'Difficult',
#    'Great Soundtrack',
#    'Third Person',
#    'Indie',
#    'Survival',
#    'Singleplayer',
#    'Soundtrack',
#    'Early Access',
#    'Bullet Hell']},
#  '96000': {'name': 'The Tiny Bang Story',
#   'rating_ratio': 6.865,
#   'price': '99',
#   'genre': ['Adventure', 'Casual', 'Indie'],
#   'tags': ['Puzzle',
#    'Point & Click',
#    'Hand-drawn',
#    'Steampunk',
#    'Retro',
#    'Atmospheric',
#    '2D',
#    'Story Rich',
#    'Casual',
#    'Family Friendly',
#    'Cute',
#    'Surreal',
#    'Stylized',
#    'Adventure',
#    'Hidden Object',
#    'Singleplayer',
#    'Indie',
#    'Minigames',
#    'Logic',
#    'Relaxing']},
#  '275850': {'name': "No Man's Sky",
#   'rating_ratio': 4.876,
#   'price': '2399',
#   'genre': ['Action', 'Adventure'],
#   'tags': ['Open World',
#    'Open World Survival Craft',
#    'Space',
#    'Exploration',
#    'Sci-fi',
#    'Survival',
#    'Procedural Generation',
#    'Adventure',
#    'First-Person',
#    'Multiplayer',
#    'Sandbox',
#    'Singleplayer',
#    'Atmospheric',
#    'Crafting',
#    'Space Sim',
#    'Indie',
#    'Action',
#    'Simulation',
#    'FPS',
#    'VR']},
#  '1811260': {'name': 'EA SPORTS FIFA 23',
#   'rating_ratio': 1.32,
#   'price': '0',
#   'genre': ['Simulation', 'Sports'],
#   'tags': ['Football (Soccer)',
#    'Sports',
#    'Controller',
#    'e-sports',
#    'PvP',
#    'Management',
#    'Simulation',
#    'Team-Based',
#    'Realistic',
#    'Third Person',
#    'Immersive Sim',
#    'Multiplayer',
#    'Local Multiplayer',
#    'Local Co-Op',
#    'Co-op',
#    'Singleplayer',
#    'Online Co-Op',
#    'PvE',
#    'Free to Play',
#    'LGBTQ+']},
#  '322170': {'name': 'Geometry Dash',
#   'rating_ratio': 14.189,
#   'price': '499',
#   'genre': ['Action', 'Indie'],
#   'tags': ['Difficult',
#    'Music',
#    'Level Editor',
#    'Great Soundtrack',
#    'Precision Platformer',
#    '2D',
#    'Rhythm',
#    'Singleplayer',
#    'Colorful',
#    'Platformer',
#    'Character Customization',
#    'Indie',
#    'Arcade',
#    'Side Scroller',
#    'Family Friendly',
#    'Action',
#    'Funny',
#    'Casual',
#    'Strategy',
#    'Adventure']},
#  '1046930': {'name': 'Dota Underlords',
#   'rating_ratio': 4.634,
#   'price': '0',
#   'genre': ['Casual', 'Free To Play', 'Strategy'],
#   'tags': ['Free to Play',
#    'Strategy',
#    'Auto Battler',
#    'Casual',
#    'Multiplayer',
#    'Tactical',
#    'Chess',
#    'Turn-Based Tactics',
#    'Turn-Based',
#    'Mature',
#    'Competitive',
#    'Fantasy',
#    'Board Game',
#    'Card Game',
#    'Deckbuilding',
#    'Singleplayer',
#    'PvP',
#    'Co-op',
#    'Automation',
#    'MOBA']},
#  '49520': {'name': 'Borderlands 2',
#   'rating_ratio': 15.416,
#   'price': '499',
#   'genre': ['Action', 'RPG'],
#   'tags': ['Loot',
#    'Shooter',
#    'Action',
#    'Multiplayer',
#    'Co-op',
#    'Looter Shooter',
#    'FPS',
#    'RPG',
#    'First-Person',
#    'Funny',
#    'Comedy',
#    'Open World',
#    'Combat',
#    'Online Co-Op',
#    'Adventure',
#    'Action RPG',
#    'Dark Humor',
#    'Singleplayer',
#    'Memes',
#    'Sci-fi']},
#  '224260': {'name': 'No More Room in Hell',
#   'rating_ratio': 8.889,
#   'price': '0',
#   'genre': ['Action', 'Indie', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Zombies',
#    'Multiplayer',
#    'Survival',
#    'Horror',
#    'Co-op',
#    'Online Co-Op',
#    'Action',
#    'FPS',
#    'First-Person',
#    'Survival Horror',
#    'Shooter',
#    'Post-apocalyptic',
#    'Open World',
#    'Realistic',
#    'Indie',
#    'Atmospheric',
#    'Mod',
#    'Adventure',
#    'Massively Multiplayer']},
#  '489520': {'name': 'Minion Masters',
#   'rating_ratio': 8.565,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Indie', 'RPG', 'Strategy', 'Free To Play'],
# ...
#    'Indie',
#    'Co-op']},
#  '219740': {'name': "Don't Starve",
#   'rating_ratio': 28.813,
#   'price': '999',
#   'genre': ['Adventure', 'Indie', 'Simulation'],
#   'tags': ['Survival',
#    'Open World Survival Craft',
#    'Crafting',
#    'Adventure',
#    'Indie',
#    'Sandbox',
#    'Singleplayer',
#    'Perma Death',
#    'Multiplayer',
#    'Open World',
#    'Exploration',
#    'Rogue-like',
#    'Replay Value',
#    'Moddable',
#    'Difficult',
#    'Simulation',
#    '2D',
#    'Top-Down',
#    'Survival Horror',
#    'Horror']},
#  '967050': {'name': 'Pacify',
#   'rating_ratio': 6.467,
#   'price': '374',
#   'genre': ['Action', 'Adventure', 'Casual', 'Indie', 'Strategy'],
#   'tags': ['Horror',
#    'Online Co-Op',
#    'Multiplayer',
#    'Psychological Horror',
#    'Co-op',
#    'Survival Horror',
#    'Exploration',
#    'First-Person',
#    'Supernatural',
#    'Sci-fi',
#    'Dark',
#    'Procedural Generation',
#    'Demons',
#    'Mystery',
#    'Action-Adventure',
#    'PvE',
#    'Thriller',
#    'Atmospheric',
#    'Adventure',
#    'Time Management']},
#  '367500': {'name': "Dragon's Dogma: Dark Arisen",
#   'rating_ratio': 7.719,
#   'price': '2999',
#   'genre': ['Action', 'Adventure', 'RPG'],
#   'tags': ['RPG',
#    'Open World',
#    'Character Customization',
#    'Fantasy',
#    'Action',
#    'Adventure',
#    'Singleplayer',
#    'Action RPG',
#    'Dragons',
#    'Dark Fantasy',
#    'Third Person',
#    'Magic',
#    'Exploration',
#    'Atmospheric',
#    'Great Soundtrack',
#    'Story Rich',
#    'Difficult',
#    'Multiplayer',
#    'JRPG',
#    'Hack and Slash']},
#  '1363080': {'name': 'Manor Lords',
#   'rating_ratio': 6.477,
#   'price': '2799',
#   'genre': ['Simulation', 'Strategy', 'Early Access'],
#   'tags': ['Strategy',
#    'City Builder',
#    'Simulation',
#    'Base-Building',
#    'Management',
#    'Building',
#    'Sandbox',
#    'Historical',
#    'Resource Management',
#    '4X',
#    'RTS',
#    'Open World',
#    'Economy',
#    'Singleplayer',
#    'Grand Strategy',
#    'Colony Sim',
#    'Replay Value',
#    'Moddable',
#    'Early Access',
#    'Real-Time with Pause']},
#  '286690': {'name': 'Metro 2033 Redux',
#   'rating_ratio': 9.646,
#   'price': '1999',
#   'genre': ['Action'],
#   'tags': ['Post-apocalyptic',
#    'FPS',
#    'Atmospheric',
#    'Story Rich',
#    'Action',
#    'Horror',
#    'Singleplayer',
#    'First-Person',
#    'Shooter',
#    'Stealth',
#    'Survival Horror',
#    'Based On A Novel',
#    'Survival',
#    'Adventure',
#    'Remake',
#    'Multiplayer',
#    'Gore',
#    'Mature',
#    'Classic',
#    'Open World']},
#  '1372880': {'name': 'The Day Before',
#   'rating_ratio': 0.187,
#   'price': '0',
#   'genre': ['Action', 'Adventure', 'Massively Multiplayer', 'Early Access'],
#   'tags': ['Multiplayer',
#    'Zombies',
#    'Extraction Shooter',
#    'Post-apocalyptic',
#    'Third-Person Shooter',
#    'Survival',
#    'PvP',
#    'Shooter',
#    'Action',
#    'Co-op',
#    'Online Co-Op',
#    'Loot',
#    'Combat',
#    'America',
#    'Adventure',
#    'PvE',
#    'Early Access',
#    'Singleplayer',
#    'Realistic',
#    'Base-Building']},
#  '1366800': {'name': 'Crosshair X',
#   'rating_ratio': 14.079,
#   'price': '899',
#   'genre': ['Action',
#    'Adventure',
#    'Indie',
#    'Animation & Modeling',
#    'Design & Illustration',
#    'Education',
#    'Photo Editing',
#    'Utilities',
#    'Game Development'],
#   'tags': ['Action',
#    'Indie',
#    'Adventure',
#    'Utilities',
#    'Shooter',
#    'Software',
#    'FPS',
#    'Game Development',
#    'Design & Illustration',
#    'Animation & Modeling',
#    'Photo Editing',
#    'Survival',
#    'Education',
#    'Third-Person Shooter',
#    'First-Person',
#    'PvP',
#    'War',
#    'Tactical',
#    'Multiplayer',
#    'Third Person']},
#  '2567870': {'name': 'Chained Together',
#   'rating_ratio': 9.796,
#   'price': '499',
#   'genre': ['Adventure', 'Casual', 'Indie', 'Simulation'],
#   'tags': ['Co-op',
#    'Adventure',
#    'Casual',
#    'Platformer',
#    'Puzzle-Platformer',
#    'Simulation',
#    'Action-Adventure',
#    '3D Platformer',
#    'Third Person',
#    'Exploration',
#    'Funny',
#    'Online Co-Op',
#    'Multiplayer',
#    'Mystery',
#    'Post-apocalyptic',
#    'Emotional',
#    'Physics',
#    'Surreal',
#    'Controller',
#    'Choices Matter']},
#  '845070': {'name': 'The Awesome Adventures of Captain Spirit',
#   'rating_ratio': 12.72,
#   'price': '0',
#   'genre': ['Adventure', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Story Rich',
#    'Adventure',
#    'Choices Matter',
#    'Atmospheric',
#    'Singleplayer',
#    'Great Soundtrack',
#    'Drama',
#    'Superhero',
#    'Short',
#    'Point & Click',
#    'Walking Simulator',
#    'Third Person',
#    'Controller',
#    'Casual',
#    'Emotional',
#    'Action',
#    'Cute',
#    'Indie',
#    'Memes']},
#  '246620': {'name': 'Plague Inc: Evolved',
#   'rating_ratio': 17.175,
#   'price': '1499',
#   'genre': ['Casual', 'Indie', 'Simulation', 'Strategy'],
#   'tags': ['Strategy',
#    'Simulation',
#    'Outbreak Sim',
#    'Indie',
#    'Singleplayer',
#    'Multiplayer',
#    'Zombies',
#    'Casual',
#    'Tactical',
#    'Replay Value',
#    'Post-apocalyptic',
#    'Addictive',
#    'Realistic',
#    '2D',
#    'Difficult',
#    'Atmospheric',
#    'Co-op',
#    'Sandbox',
#    'Early Access',
#    'Survival']},
#  '55230': {'name': 'Saints Row: The Third',
#   'rating_ratio': 22.272,
#   'price': '999',
#   'genre': ['Action'],
#   'tags': ['Open World',
#    'Action',
#    'Comedy',
#    'Co-op',
#    'Third-Person Shooter',
#    'Funny',
#    'Character Customization',
#    'Sandbox',
#    'Third Person',
#    'Online Co-Op',
#    'Singleplayer',
#    'Great Soundtrack',
#    'Multiplayer',
#    'Shooter',
#    'Crime',
#    'Female Protagonist',
#    'Adventure',
#    'Satire',
#    'Zombies',
#    'RPG']},
#  '703080': {'name': 'Planet Zoo',
#   'rating_ratio': 10.224,
#   'price': '4499',
#   'genre': ['Casual', 'Simulation', 'Strategy'],
#   'tags': ['Management',
#    'Simulation',
#    'Building',
#    'Sandbox',
#    'Nature',
#    'City Builder',
#    'Economy',
#    'Realistic',
#    'Singleplayer',
#    'Family Friendly',
#    'Cute',
#    'Resource Management',
#    'Strategy',
#    'Great Soundtrack',
#    'Multiplayer',
#    'Relaxing',
#    'Open World',
#    'Casual',
#    'Funny',
#    'Horses']},
#  '648350': {'name': 'Jurassic World Evolution',
#   'rating_ratio': 6.824,
#   'price': '4499',
#   'genre': ['Simulation', 'Strategy'],
#   'tags': ['Building',
#    'Dinosaurs',
#    'Simulation',
#    'Management',
#    'Strategy',
#    'Sandbox',
#    'Singleplayer',
#    'City Builder',
#    'Sci-fi',
#    'Resource Management',
#    'Economy',
#    'Open World',
#    'Atmospheric',
#    'Violent',
#    'Action',
#    'Multiplayer',
#    'Great Soundtrack',
#    'Survival',
#    'Casual',
#    'Adventure']},
#  '550900': {'name': 'Metin2',
#   'rating_ratio': 2.349,
#   'price': '0',
#   'genre': ['Action',
#    'Adventure',
#    'Free To Play',
#    'Massively Multiplayer',
#    'RPG'],
#   'tags': ['Free to Play',
#    'MMORPG',
#    'PvP',
#    'Action RPG',
#    'PvE',
#    'Massively Multiplayer',
#    'Hack and Slash',
#    'Adventure',
#    'RPG',
#    'Multiplayer',
#    'Action',
#    'Fantasy',
#    'Strategy',
#    'Action-Adventure',
#    'Casual',
#    'Fighting',
#    'Trading',
#    'Third Person',
#    'Spectacle fighter',
#    'Class-Based']},
#  '287390': {'name': 'Metro: Last Light Redux',
#   'rating_ratio': 9.573,
#   'price': '1999',
#   'genre': ['Action'],
#   'tags': ['Post-apocalyptic',
#    'FPS',
#    'Atmospheric',
#    'Action',
#    'Story Rich',
#    'Horror',
#    'Singleplayer',
#    'First-Person',
#    'Shooter',
#    'Stealth',
#    'Survival',
#    'Based On A Novel',
#    'Adventure',
#    'Survival Horror',
#    'Nudity',
#    'Remake',
#    'Sci-fi',
#    'Multiplayer',
#    'Difficult',
#    'Open World']},
#  '242720': {'name': 'GunZ 2: The Second Duel',
#   'rating_ratio': 1.951,
#   'price': '0',
#   'genre': ['Action', 'Indie', 'Free To Play'],
#   'tags': ['Free to Play',
#    'Action',
#    'Multiplayer',
#    'Third-Person Shooter',
#    'Hack and Slash',
#    'Shooter',
#    'Fast-Paced',
#    'Co-op',
#    'PvP',
#    'Parkour',
#    'Third Person',
#    'Fighting',
#    'FPS',
#    'Massively Multiplayer',
#    'RPG',
#    'Indie',
#    'Adventure',
#    'Singleplayer',
#    'Strategy',
#    'First-Person']},
#  '407530': {'name': 'ARK: Survival Of The Fittest',
#   'rating_ratio': 1.977,
#   'price': '1499',
#   'genre': ['Action',
#    'Adventure',
#    'Indie',
#    'Massively Multiplayer',
#    'RPG',
#    'Strategy'],
#   'tags': ['Free to Play',
#    'Survival',
#    'Dinosaurs',
#    'Multiplayer',
#    'Open World',
#    'Action',
#    'Adventure',
#    'Massively Multiplayer',
#    'PvP',
#    'Dragons',
#    'Early Access',
#    'Crafting',
#    'RPG',
#    'First-Person',
#    'Singleplayer',
#    'Strategy',
#    'Exploration',
#    'FPS',
#    'Sandbox',
#    'Indie']},
#  '581320': {'name': 'Insurgency: Sandstorm',
#   'rating_ratio': 5.674,
#   'price': '2999',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Realistic',
#    'Shooter',
#    'Military',
#    'Tactical',
#    'Multiplayer',
#    'Action',
#    'First-Person',
#    'War',
#    'Online Co-Op',
#    'Co-op',
#    'Gore',
#    'Violent',
#    'Difficult',
#    'Atmospheric',
#    'Simulation',
#    'Open World',
#    'Massively Multiplayer',
#    'Indie',
#    'Choices Matter']},
#  '316010': {'name': 'Magic Duels',
#   'rating_ratio': 2.441,
#   'price': '0',
#   'genre': ['Free To Play', 'Strategy'],
#   'tags': ['Free to Play',
#    'Card Game',
#    'Trading Card Game',
#    'Magic',
#    'Strategy',
#    'Multiplayer',
#    'Fantasy',
#    'Singleplayer',
#    'Co-op',
#    'Turn-Based',
#    'Online Co-Op',
#    'Great Soundtrack',
#    'Action',
#    'Board Game',
#    'Casual',
#    'Funny']},
#  '1172380': {'name': 'STAR WARS Jedi: Fallen Order',
#   'rating_ratio': 7.757,
#   'price': '3999',
#   'genre': ['Action', 'Adventure'],
#   'tags': ['Action-Adventure',
#    'Souls-like',
#    'Third Person',
#    'Open World',
#    'Story Rich',
#    'Swordplay',
#    'Exploration',
#    'Sci-fi',
#    'Action',
#    'Platformer',
#    'Space',
#    'RPG',
#    'Fighting',
#    'Puzzle',
#    'Adventure',
#    'Metroidvania',
#    'Fantasy',
#    'Atmospheric',
#    'Hack and Slash',
#    'Family Friendly']},
#  '11020': {'name': 'TrackMania Nations Forever',
#   'rating_ratio': 8.972,
#   'price': '0',
#   'genre': ['Racing'],
#   'tags': ['Racing',
#    'Free to Play',
#    'Multiplayer',
#    'Automobile Sim',
#    'Singleplayer',
#    'Level Editor',
#    'Arcade',
#    'Competitive',
#    'Simulation',
#    'Controller',
#    'Massively Multiplayer',
#    'Action',
#    'Sports',
#    'Difficult',
#    'Sandbox',
#    'Casual',
#    'Adventure',
#    'Co-op',
#    'First-Person',
#    'Indie']},
#  '47870': {'name': 'Need For Speed: Hot Pursuit',
#   'rating_ratio': 4.725,
#   'price': '0',
#   'genre': ['Racing'],
#   'tags': ['Racing',
#    'Combat Racing',
#    'Sports',
#    'Driving',
#    'PvP',
#    'Automobile Sim',
#    'Open World',
#    'Arcade',
#    'Third Person',
#    'First-Person',
#    'Simulation',
#    'Atmospheric',
#    'Multiplayer',
#    'Online Co-Op',
#    'Adventure',
#    'Co-op',
#    'Action',
#    'Singleplayer',
#    'Controller',
#    'Great Soundtrack']},
#  '305620': {'name': 'The Long Dark',
#   'rating_ratio': 9.778,
#   'price': '1999',
#   'genre': ['Adventure', 'Indie', 'Simulation', 'Strategy'],
#   'tags': ['Survival',
#    'Open World Survival Craft',
#    'Open World',
#    'Exploration',
#    'Atmospheric',
#    'Singleplayer',
#    'First-Person',
#    'Adventure',
#    'Crafting',
#    'Sandbox',
#    'Simulation',
#    'Post-apocalyptic',
#    'Indie',
#    'Walking Simulator',
#    'Survival Horror',
#    'Strategy',
#    'Difficult',
#    'Action',
#    'Co-op',
#    'Early Access']},
#  '3097560': {'name': "Liar's Bar",
#   'rating_ratio': 11.125,
#   'price': '699',
#   'genre': ['Casual', 'Indie', 'Simulation', 'Strategy', 'Early Access'],
#   'tags': ['Multiplayer',
#    'Casual',
#    'PvP',
#    'Co-op',
#    'Online Co-Op',
#    'Gambling',
#    'Indie',
#    'FPS',
#    'Funny',
#    '3D',
#    'First-Person',
#    'Dark',
#    'Tabletop',
#    'Puzzle',
#    'Horror',
#    'Board Game',
#    'Strategy',
#    'Gore',
#    'VR',
#    'Early Access']},
#  '1274570': {'name': 'DEVOUR',
#   'rating_ratio': 10.134,
#   'price': '999',
#   'genre': ['Indie'],
#   'tags': ['Horror',
#    'Online Co-Op',
#    'Multiplayer',
#    'Survival Horror',
#    'Sexual Content',
#    'Co-op',
#    'Psychological Horror',
#    'Dark',
#    'Survival',
#    'First-Person',
#    'Atmospheric',
#    'VR',
#    'Indie',
#    'Difficult',
#    'Gore',
#    'Puzzle',
#    'Singleplayer',
#    'Violent',
#    'Action',
#    'Stealth']},
#  '221040': {'name': 'Resident Evil 6',
#   'rating_ratio': 3.674,
#   'price': '1999',
#   'genre': ['Action', 'Adventure'],
#   'tags': ['Action',
#    'Zombies',
#    'Co-op',
#    'Third-Person Shooter',
#    'Horror',
#    'Co-op Campaign',
#    'Online Co-Op',
#    'Multiplayer',
#    'Adventure',
#    'Split Screen',
#    'Third Person',
#    'Local Co-Op',
#    'Shooter',
#    'Quick-Time Events',
#    'Survival Horror',
#    'Survival',
#    'Singleplayer',
#    'Female Protagonist',
#    'Atmospheric',
#    'Gore']},
#  '427730': {'name': "Who's Your Daddy?!",
#   'rating_ratio': 3.978,
#   'price': '699',
#   'genre': ['Action', 'Casual', 'Indie'],
#   'tags': ['Funny',
#    'Multiplayer',
#    'First-Person',
#    'Comedy',
#    'Simulation',
#    'Online Co-Op',
#    'Strategy',
#    'Dark Humor',
#    'Co-op',
#    'Casual',
#    'Indie',
#    'Split Screen',
#    'Action',
#    'Early Access',
#    'Difficult',
#    'Sandbox',
#    'Third Person',
#    'Survival',
#    'Adventure',
#    'Singleplayer']},
#  '105450': {'name': 'Age of Empires III (2007)',
#   'rating_ratio': 10.014,
#   'price': '0',
#   'genre': ['Simulation', 'Strategy'],
#   'tags': ['Strategy',
#    'RTS',
#    'Base-Building',
#    'Multiplayer',
#    'Historical',
#    'Resource Management',
#    'City Builder',
#    'War',
#    'Simulation',
#    'Singleplayer',
#    'Real-Time',
#    'Military',
#    'Classic',
#    'Building',
#    'Open World',
#    'Co-op',
#    'Action',
#    'Online Co-Op',
#    'Real-Time with Pause',
#    'Adventure']},
#  '8850': {'name': 'BioShock 2',
#   'rating_ratio': 8.342,
#   'price': '299',
#   'genre': ['Action'],
#   'tags': ['FPS',
#    'Action',
#    'Singleplayer',
#    'Atmospheric',
#    'Story Rich',
#    'Horror',
#    'First-Person',
#    'Shooter',
#    'Steampunk',
#    'Sci-fi',
#    'Multiplayer',
#    'Underwater',
#    'Dystopian ',
#    'Adventure',
#    'Immersive',
#    'RPG',
#    'Dark',
#    'Great Soundtrack',
#    'Philosophical',
#    'Action RPG']},
#  '24200': {'name': 'DC Universe Online',
#   'rating_ratio': 4.148,
#   'price': '0',
#   'genre': ['Action',
#    'Adventure',
#    'Massively Multiplayer',
#    'RPG',
#    'Free To Play'],
#   'tags': ['Free to Play',
#    'Superhero',
#    'MMORPG',
#    'Massively Multiplayer',
#    'Character Customization',
#    'Action',
#    'Comic Book',
#    'RPG',
#    'Adventure',
#    'Multiplayer',
#    'Controller',
#    'Third Person',
#    'Open World',
#    'Combat',
#    "Beat 'em up",
#    'Exploration',
#    'PvP',
#    'Fighting',
#    'Online Co-Op',
#    'Co-op']},
#  '248570': {'name': 'Toribash',
#   'rating_ratio': 7.714,
#   'price': '0',
#   'genre': ['Action', 'Indie', 'Strategy', 'Free To Play'],
#   'tags': ['Free to Play',
#    '3D Fighter',
#    'Fighting',
#    'Physics',
#    'Multiplayer',
#    'Gore',
#    'Action',
#    'Strategy',
#    'Turn-Based',
#    'Martial Arts',
#    'Funny',
#    'Indie',
#    'Blood',
#    'Simulation',
#    'Sandbox',
#    'Moddable',
#    'Difficult',
#    'Parkour',
#    'Singleplayer',
#    'Turn-Based Strategy']},
#  '286570': {'name': 'F1 2015',
#   'rating_ratio': 1.483,
#   'price': '0',
#   'genre': ['Racing', 'Sports'],
#   'tags': ['Racing',
#    'Automobile Sim',
#    'Sports',
#    'Simulation',
#    'Driving',
#    'Multiplayer',
#    'Realistic',
#    'Singleplayer',
#    'Co-op',
#    'Action',
#    'First-Person',
#    'Controller']},
#  '203290': {'name': "America's Army: Proving Grounds",
#   'rating_ratio': 3.739,
#   'price': '0',
#   'genre': ['Action', 'Free To Play'],
#   'tags': ['Free to Play',
#    'FPS',
#    'Action',
#    'Multiplayer',
#    'Military',
#    'Shooter',
#    'Tactical',
#    'First-Person',
#    'Singleplayer',
#    'America',
#    'War',
#    'Realistic',
#    'Open World',
#    'Co-op',
#    'Simulation',
#    'Strategy',
#    'Massively Multiplayer',
#    'Survival',
#    'Adventure',
#    'Atmospheric']},
#  '641990': {'name': 'The Escapists 2',
#   'rating_ratio': 9.665,
#   'price': '539',
#   'genre': ['Indie', 'Simulation', 'Strategy'],
#   'tags': ['Multiplayer',
#    'Strategy',
#    'Pixel Graphics',
#    'Online Co-Op',
#    'Co-op',
#    '2D',
#    'Crafting',
#    'Local Co-Op',
#    'Simulation',
#    'Singleplayer',
#    'Indie',
#    'Sandbox',
#    'Stealth',
#    'Character Customization',
#    'Funny',
#    'Puzzle',
#    'Split Screen',
#    'Open World',
#    'Action',
#    'Difficult']}}

# %% [markdown]
# ## Export data to CSV

# %%
csv_filename = "game_library_data.csv"

with open(csv_filename, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)

    header = ["game_id", "name", "rating_ratio", "price", "genre", "tags"]
    writer.writerow(header)

    for game_id, game_data in all_games_detailed.items():
        writer.writerow([
            game_id,
            game_data["name"],
            game_data["rating_ratio"],
            game_data["price"],
            ", ".join(game_data["genre"]),
            ", ".join(game_data["tags"])
        ])

# %% [markdown]
# # Part 2: Generate synthetic player-owned game libraries

# %% [markdown]
# ### Get unique list of genres

# %%
unique_genres = set()
for game_id, game_data in all_games_detailed.items():
    genres = game_data["genre"]
    for genre in genres:
        unique_genres.add(genre.strip())

unique_genres
# Out:
# {'',
#  'Action',
#  'Adventure',
#  'Animation & Modeling',
#  'Casual',
#  'Design & Illustration',
#  'Early Access',
#  'Education',
#  'Free To Play',
#  'Game Development',
#  'Indie',
#  'Massively Multiplayer',
#  'Photo Editing',
#  'RPG',
#  'Racing',
#  'Simulation',
#  'Sports',
#  'Strategy',
#  'Utilities',
#  'Video Production'}

# %%
remove_genres = ['Video Production', 'Early Access', 'Free To Play', 'Animation & Modeling',
    'Design & Illustration', 'Education', 'Photo Editing', 'Utilities', '', 'Game Development']

for genre in remove_genres:
    if genre in unique_genres:
        unique_genres.remove(genre)

unique_genres
# Out:
# {'Action',
#  'Adventure',
#  'Casual',
#  'Indie',
#  'Massively Multiplayer',
#  'RPG',
#  'Racing',
#  'Simulation',
#  'Sports',
#  'Strategy'}

# %% [markdown]
# ### Create genre-to-games mapping

# %%
genre_game_map = {}
for genre in unique_genres:
  genre_game_map[genre] = []

for game_id, game_data in all_games_detailed.items():
  for genre in game_data["genre"]:
    genre = genre.strip()
    if genre in genre_game_map:
      genre_game_map[genre].append((game_id, game_data["name"]))

genre_game_map
# Out:
# {'Sports': [('1097150', 'Fall Guys: Ultimate Knockout'),
#   ('438100', 'VRChat'),
#   ('252950', 'Rocket League'),
#   ('417910', 'Street Warriors Online'),
#   ('1089350', 'NBA 2K20'),
#   ('1811260', 'EA SPORTS FIFA 23'),
#   ('518790', 'theHunter: Call of the Wild'),
#   ('244210', 'Assetto Corsa'),
#   ('253710', 'theHunter Classic'),
#   ('211500', 'RaceRoom Racing Experience'),
#   ('2195250', 'EA SPORTS FC 24'),
#   ('766570', 'Russian Fishing 4'),
#   ('1551360', 'Forza Horizon 5'),
#   ('1100600', 'Football Manager 2020'),
#   ('380600', 'Fishing Planet'),
#   ('1225330', 'NBA 2K21'),
#   ('1222680', 'Need for Speed Heat'),
#   ('1506830', 'FIFA 22'),
#   ('389730', 'TEKKEN 7'),
#   ('339610', 'Freestyle 2: Street Basketball'),
#   ('286570', 'F1 2015')],
#  'Racing': [('252950', 'Rocket League'),
#   ('284160', 'BeamNG.drive'),
#   ('244210', 'Assetto Corsa'),
#   ('1293830', 'Forza Horizon 4'),
#   ('211500', 'RaceRoom Racing Experience'),
#   ('1551360', 'Forza Horizon 5'),
#   ('386180', 'Crossout'),
#   ('1222680', 'Need for Speed Heat'),
#   ('516750', 'My Summer Car'),
#   ('918570', 'Century: Age of Ashes'),
#   ('646910', 'The Crew 2'),
#   ('11020', 'TrackMania Nations Forever'),
#   ('47870', 'Need For Speed: Hot Pursuit'),
#   ('286570', 'F1 2015')],
#  'Massively Multiplayer': [('578080', 'PUBG: BATTLEGROUNDS'),
#   ('1063730', 'New World: Aeternum'),
#   ('1599340', 'Lost Ark'),
#   ('236390', 'War Thunder'),
#   ('252490', 'Rust'),
#   ('346110', 'ARK: Survival Evolved'),
#   ('238960', 'Path of Exile'),
#   ('1203220', 'NARAKA: BLADEPOINT'),
#   ('1097150', 'Fall Guys: Ultimate Knockout'),
#   ('444090', 'Paladins'),
#   ('552990', 'World of Warships'),
#   ('438100', 'VRChat'),
#   ('227940', 'Heroes & Generals'),
#   ('386360', 'SMITE'),
#   ('444200', 'World of Tanks Blitz'),
#   ('755790', 'Ring of Elysium'),
#   ('301520', 'Robocraft'),
#   ('417910', 'Street Warriors Online'),
#   ('433850', 'Z1 Battle Royale'),
#   ('304050', 'Trove'),
#   ('221100', 'DayZ'),
#   ('1407200', 'World of Tanks'),
#   ('218230', 'PlanetSide 2'),
#   ('582660', 'Black Desert'),
#   ('2694490', 'Path of Exile 2'),
#   ('306130', 'The Elder Scrolls Online'),
#   ('1286830', 'STAR WARS: The Old Republic'),
#   ('109600', 'Neverwinter'),
#   ('397900', 'Business Tour - Board Game with Online Multiplayer'),
#   ('273110', 'Counter-Strike Nexon: Studio'),
#   ('555570', 'Infestation: The New Z'),
#   ('868270', 'The Cycle'),
#   ('766570', 'Russian Fishing 4'),
#   ('113400', 'APB Reloaded'),
#   ('386180', 'Crossout'),
#   ('200210', 'Realm of the Mad God Exalt'),
#   ('380600', 'Fishing Planet'),
#   ('39210', 'FINAL FANTASY XIV Online'),
#   ('1677740', 'Stumble Guys'),
#   ('1238840', 'Battlefield 1'),
#   ('761890', 'Albion Online'),
#   ('1604030', 'V Rising'),
#   ('513710', 'SCUM'),
#   ('744900', 'Dead Frontier 2'),
#   ('355840', 'Survarium'),
#   ('212500', 'The Lord of the Rings Online'),
#   ('1180380', 'Stay Out'),
#   ('671860', 'BattleBit Remastered'),
#   ('8500', 'EVE Online'),
#   ('884660', 'CRSED: F.O.A.D.'),
#   ('440900', 'Conan Exiles'),
#   ('376210', 'The Isle'),
#   ('418460', 'Rising Storm 2: Vietnam'),
#   ('339610', 'Freestyle 2: Street Basketball'),
#   ('35450', 'Red Orchestra 2: Heroes of Stalingrad with Rising Storm'),
#   ('335240', 'Transformice'),
#   ('99900', 'Spiral Knights'),
#   ('359320', 'Elite Dangerous'),
#   ('299360', 'Block N Load'),
#   ('224600', 'Defiance'),
#   ('291480', 'Warface'),
#   ('905370', "Conqueror's Blade"),
#   ('436150', 'Governor of Poker 3'),
#   ('269210', 'Hero Siege'),
#   ('372000', 'Tree of Savior (English Ver.)'),
#   ('686810', 'Hell Let Loose'),
#   ('1056640', 'Phantasy Star Online 2'),
#   ('646910', 'The Crew 2'),
#   ('1372880', 'The Day Before'),
#   ('550900', 'Metin2'),
#   ('407530', 'ARK: Survival Of The Fittest'),
#   ('24200', 'DC Universe Online')],
#  'Casual': [('304930', 'Unturned'),
#   ('4000', "Garry's Mod"),
#   ('945360', 'Among Us'),
#   ('1097150', 'Fall Guys: Ultimate Knockout'),
#   ('438100', 'VRChat'),
#   ('1517290', 'Battlefield 2042'),
#   ('386360', 'SMITE'),
#   ('477160', 'Human Fall Flat'),
#   ('1222670', 'The Sims 4'),
#   ('304050', 'Trove'),
#   ('204360', 'Castle Crashers'),
#   ('96000', 'The Tiny Bang Story'),
#   ('1046930', 'Dota Underlords'),
#   ('278360', 'A Story About My Uncle'),
#   ('1794680', 'Vampire Survivors'),
#   ('363970', 'Clicker Heroes'),
#   ('225840', 'Sven Co-op'),
#   ('238460', 'BattleBlock Theater'),
#   ('308600', 'Gene Shift Auto'),
#   ('427520', 'Factorio'),
#   ('1118200', 'People Playground'),
#   ('397900', 'Business Tour - Board Game with Online Multiplayer'),
#   ('698780', 'Doki Doki Literature Club!'),
#   ('273110', 'Counter-Strike Nexon: Studio'),
#   ('766570', 'Russian Fishing 4'),
#   ('346900', 'AdVenture Capitalist'),
#   ('285800', 'Braveland'),
#   ('1868140', 'DAVE THE DIVER'),
#   ('252130', 'Divide By Sheep'),
#   ('211820', 'Starbound'),
#   ('1677740', 'Stumble Guys'),
#   ('351940', 'The Descendant'),
#   ('286160', 'Tabletop Simulator'),
#   ('1817070', 'Marvel’s Spider-Man Remastered'),
#   ('674940', 'Stick Fight: The Game'),
#   ('274190', 'Broforce'),
#   ('1260320', 'Party Animals'),
#   ('728880', 'Overcooked! 2'),
#   ('339610', 'Freestyle 2: Street Basketball'),
#   ('99900', 'Spiral Knights'),
#   ('285900', 'Gang Beasts'),
#   ('880940', 'Pummel Party'),
#   ('1454400', 'Cookie Clicker'),
#   ('262410', 'World of Guns: Gun Disassembly'),
#   ('1942280', 'Brotato'),
#   ('838350', '太吾绘卷 The Scroll Of Taiwu'),
#   ('585690', 'Minimalism'),
#   ('265930', 'Goat Simulator'),
#   ('436150', 'Governor of Poker 3'),
#   ('331470', 'Everlasting Summer'),
#   ('2670630', 'Supermarket Simulator'),
#   ('967050', 'Pacify'),
#   ('2567870', 'Chained Together'),
#   ('246620', 'Plague Inc: Evolved'),
#   ('703080', 'Planet Zoo'),
#   ('3097560', "Liar's Bar"),
#   ('427730', "Who's Your Daddy?!")],
#  'Indie': [('1623730', 'Palworld'),
#   ('304930', 'Unturned'),
#   ('105600', 'Terraria'),
#   ('291550', 'Brawlhalla'),
#   ('4000', "Garry's Mod"),
#   ('252490', 'Rust'),
#   ('346110', 'ARK: Survival Evolved'),
#   ('892970', 'Valheim'),
#   ('238960', 'Path of Exile'),
#   ('242760', 'The Forest'),
#   ('322330', "Don't Starve Together"),
#   ('899770', 'Last Epoch'),
#   ('413150', 'Stardew Valley'),
#   ('1097150', 'Fall Guys: Ultimate Knockout'),
#   ('227300', 'Euro Truck Simulator 2'),
#   ('272060', 'Serena'),
#   ('739630', 'Phasmophobia'),
#   ('227940', 'Heroes & Generals'),
#   ('252950', 'Rocket League'),
#   ('1966720', 'Lethal Company'),
#   ('108600', 'Project Zomboid'),
#   ('648800', 'Raft'),
#   ('1468810', '鬼谷八荒 Tale of Immortal'),
#   ('367520', 'Hollow Knight'),
#   ('301520', 'Robocraft'),
#   ('477160', 'Human Fall Flat'),
#   ('251570', '7 Days to Die'),
#   ('219990', 'Grim Dawn'),
#   ('261550', 'Mount & Blade II: Bannerlord'),
#   ('1326470', 'Sons Of The Forest'),
#   ('526870', 'Satisfactory'),
#   ('204360', 'Castle Crashers'),
#   ('632360', 'Risk of Rain 2'),
#   ('96000', 'The Tiny Bang Story'),
#   ('322170', 'Geometry Dash'),
#   ('224260', 'No More Room in Hell'),
#   ('489520', 'Minion Masters'),
#   ('466240', 'Deceit'),
#   ('370910', 'Kathy Rain'),
#   ('278360', 'A Story About My Uncle'),
#   ('275390', 'Guacamelee! Super Turbo Championship Edition'),
#   ('2881650', 'Content Warning'),
#   ('387990', 'Scrap Mechanic'),
#   ('219640', 'Chivalry: Medieval Warfare'),
#   ('244210', 'Assetto Corsa'),
#   ('1794680', 'Vampire Survivors'),
#   ('363970', 'Clicker Heroes'),
#   ('225840', 'Sven Co-op'),
#   ('1145360', 'Hades'),
#   ('1229490', 'ULTRAKILL'),
#   ('238460', 'BattleBlock Theater'),
#   ('308600', 'Gene Shift Auto'),
#   ('427520', 'Factorio'),
#   ('629760', 'MORDHAU'),
#   ('588650', 'Dead Cells'),
#   ('646570', 'Slay the Spire'),
#   ('233450', 'Prison Architect'),
#   ('677620', 'Splitgate: Arena Warfare'),
#   ('1049590', 'Eternal Return: Black Survival'),
#   ('1118200', 'People Playground'),
#   ('268910', 'Cuphead'),
#   ('397900', 'Business Tour - Board Game with Online Multiplayer'),
#   ('698780', 'Doki Doki Literature Club!'),
#   ('273110', 'Counter-Strike Nexon: Studio'),
#   ('555570', 'Infestation: The New Z'),
#   ('391540', 'Undertale'),
#   ('294100', 'RimWorld'),
#   ('223470', 'POSTAL 2'),
#   ('1332010', 'Stray'),
#   ('232770', 'POSTAL'),
#   ('346900', 'AdVenture Capitalist'),
#   ('208090', 'Loadout'),
#   ('285800', 'Braveland'),
#   ('466560', 'Northgard'),
#   ('1116170', 'CyberCorp'),
#   ('264710', 'Subnautica'),
#   ('252130', 'Divide By Sheep'),
#   ('262060', 'Darkest Dungeon'),
#   ('211820', 'Starbound'),
#   ('200210', 'Realm of the Mad God Exalt'),
#   ('1144200', 'Ready or Not'),
#   ('1677740', 'Stumble Guys'),
#   ('238320', 'Outlast'),
#   ('508440', 'Totally Accurate Battle Simulator'),
#   ('222880', 'Insurgency'),
#   ('513710', 'SCUM'),
#   ('744900', 'Dead Frontier 2'),
#   ('244850', 'Space Engineers'),
#   ('351940', 'The Descendant'),
#   ('286160', 'Tabletop Simulator'),
#   ('212680', 'FTL: Faster Than Light'),
#   ('1366540', 'Dyson Sphere Program'),
#   ('1721470', 'Poppy Playtime'),
#   ('871720', 'Ultimate Custom Night'),
#   ('1180380', 'Stay Out'),
#   ('304430', 'INSIDE'),
#   ('311690', 'Enter the Gungeon'),
#   ('620980', 'Beat Saber'),
#   ('674940', 'Stick Fight: The Game'),
#   ('1145350', 'Hades II'),
#   ('457140', 'Oxygen Not Included'),
#   ('504230', 'Celeste'),
#   ('613100', 'House Flipper'),
#   ('270880', 'American Truck Simulator'),
#   ('48000', 'LIMBO'),
#   ('1832640', 'Mirror 2: Project X'),
#   ('274190', 'Broforce'),
#   ('312990', 'The Expendabros'),
#   ('376210', 'The Isle'),
#   ('220200', 'Kerbal Space Program'),
#   ('1260320', 'Party Animals'),
#   ('265630', 'Fistful of Frags'),
#   ('516750', 'My Summer Car'),
#   ('552500', 'Warhammer: Vermintide 2'),
#   ('728880', 'Overcooked! 2'),
#   ('439190', 'Stories: The Path of Destinies'),
#   ('245170', 'Skullgirls 2nd Encore'),
#   ('219150', 'Hotline Miami'),
#   ('424370', 'Wolcen: Lords of Mayhem'),
#   ('209080', 'Guns of Icarus Online'),
#   ('918570', 'Century: Age of Ashes'),
#   ('335240', 'Transformice'),
#   ('99900', 'Spiral Knights'),
#   ('361420', 'ASTRONEER'),
#   ('223710', 'Cry of Fear'),
#   ('1289310', 'Helltaker'),
#   ('285900', 'Gang Beasts'),
#   ('880940', 'Pummel Party'),
#   ('1454400', 'Cookie Clicker'),
#   ('362890', 'Black Mesa'),
#   ('247080', 'Crypt of the NecroDancer'),
#   ('391720', 'Layers of Fear (2016)'),
#   ('274170', 'Hotline Miami 2: Wrong Number'),
#   ('113200', 'The Binding of Isaac'),
#   ('262410', 'World of Guns: Gun Disassembly'),
#   ('1361210', 'Warhammer 40,000: Darktide'),
#   ('1942280', 'Brotato'),
#   ('838350', '太吾绘卷 The Scroll Of Taiwu'),
#   ('282070', 'This War of Mine'),
#   ('585690', 'Minimalism'),
#   ('265930', 'Goat Simulator'),
#   ('1943950', 'Escape the Backrooms'),
#   ('204880', 'Sins of a Solar Empire: Rebellion'),
#   ('269210', 'Hero Siege'),
#   ('686810', 'Hell Let Loose'),
#   ('65800', 'Dungeon Defenders'),
#   ('331470', 'Everlasting Summer'),
#   ('233860', 'Kenshi'),
#   ('239030', 'Papers, Please'),
#   ('992300', '嗜血印 Bloody Spell'),
#   ('2670630', 'Supermarket Simulator'),
#   ('219740', "Don't Starve"),
#   ('967050', 'Pacify'),
#   ('1366800', 'Crosshair X'),
#   ('2567870', 'Chained Together'),
#   ('246620', 'Plague Inc: Evolved'),
#   ('242720', 'GunZ 2: The Second Duel'),
#   ('407530', 'ARK: Survival Of The Fittest'),
#   ('305620', 'The Long Dark'),
#   ('3097560', "Liar's Bar"),
#   ('1274570', 'DEVOUR'),
#   ('427730', "Who's Your Daddy?!"),
#   ('248570', 'Toribash'),
#   ('641990', 'The Escapists 2')],
#  'Action': [('570', 'Dota 2'),
#   ('730', 'Counter-Strike: Global Offensive'),
#   ('578080', 'PUBG: BATTLEGROUNDS'),
#   ('1623730', 'Palworld'),
#   ('1172470', 'Apex Legends'),
#   ('1063730', 'New World: Aeternum'),
#   ('2358720', 'Black Myth: Wukong'),
#   ('1938090', 'Call of Duty: Modern Warfare II'),
#   ('271590', 'Grand Theft Auto V Legacy'),
#   ('550', 'Left 4 Dead 2'),
#   ('553850', 'HELLDIVERS 2'),
#   ('1599340', 'Lost Ark'),
#   ('304930', 'Unturned'),
#   ('236390', 'War Thunder'),
#   ('1245620', 'ELDEN RING'),
#   ('105600', 'Terraria'),
#   ('440', 'Team Fortress 2'),
#   ('291550', 'Brawlhalla'),
#   ('359550', "Tom Clancy's Rainbow Six Siege"),
#   ('1085660', 'Destiny 2'),
#   ('252490', 'Rust'),
#   ('346110', 'ARK: Survival Evolved'),
#   ('892970', 'Valheim'),
#   ('218620', 'PAYDAY 2'),
#   ('901583', 'Grand Theft Auto IV: Complete Edition'),
#   ('238960', 'Path of Exile'),
#   ('242760', 'The Forest'),
#   ('322330', "Don't Starve Together"),
#   ('1203220', 'NARAKA: BLADEPOINT'),
#   ('899770', 'Last Epoch'),
#   ('340', 'Half-Life 2: Lost Coast'),
#   ('381210', 'Dead by Daylight'),
#   ('1097150', 'Fall Guys: Ultimate Knockout'),
#   ('444090', 'Paladins'),
#   ('552990', 'World of Warships'),
#   ('320', 'Half-Life 2: Deathmatch'),
#   ('739630', 'Phasmophobia'),
#   ('990080', 'Hogwarts Legacy'),
#   ('620', 'Portal 2'),
#   ('227940', 'Heroes & Generals'),
#   ('70', 'Half-Life'),
#   ('252950', 'Rocket League'),
#   ('1966720', 'Lethal Company'),
#   ('1517290', 'Battlefield 2042'),
#   ('1240440', 'Halo Infinite'),
#   ('582010', 'Monster Hunter: World'),
#   ('240', 'Counter-Strike: Source'),
#   ('386360', 'SMITE'),
#   ('10', 'Counter-Strike'),
#   ('1468810', '鬼谷八荒 Tale of Immortal'),
#   ('444200', 'World of Tanks Blitz'),
#   ('755790', 'Ring of Elysium'),
#   ('1174180', 'Red Dead Redemption 2'),
#   ('250900', 'The Binding of Isaac: Rebirth'),
#   ('550650', 'Black Squad'),
#   ('367520', 'Hollow Knight'),
#   ('301520', 'Robocraft'),
#   ('239140', 'Dying Light'),
#   ('251570', '7 Days to Die'),
#   ('814380', 'Sekiro: Shadows Die Twice - GOTY Edition'),
#   ('417910', 'Street Warriors Online'),
#   ('433850', 'Z1 Battle Royale'),
#   ('594650', 'Hunt: Showdown 1896'),
#   ('220', 'Half-Life 2'),
#   ('230410', 'Warframe'),
#   ('219990', 'Grim Dawn'),
#   ('261550', 'Mount & Blade II: Bannerlord'),
#   ('304050', 'Trove'),
#   ('107410', 'Arma 3'),
#   ('1326470', 'Sons Of The Forest'),
#   ('1238810', 'Battlefield V'),
#   ('60', 'Ricochet'),
#   ('221100', 'DayZ'),
#   ('204360', 'Castle Crashers'),
#   ('632360', 'Risk of Rain 2'),
#   ('275850', "No Man's Sky"),
#   ('322170', 'Geometry Dash'),
#   ('49520', 'Borderlands 2'),
#   ('224260', 'No More Room in Hell'),
#   ('489520', 'Minion Masters'),
#   ('80', 'Counter-Strike: Condition Zero'),
#   ('466240', 'Deceit'),
#   ('300', 'Day of Defeat: Source'),
#   ('275390', 'Guacamelee! Super Turbo Championship Edition'),
#   ('374320', 'DARK SOULS III'),
#   ('700330', 'SCP: Secret Laboratory'),
#   ('311210', 'Call of Duty: Black Ops III'),
#   ('1172620', 'Sea of Thieves: 2025 Edition'),
#   ('1407200', 'World of Tanks'),
#   ('2050650', 'Resident Evil 4'),
#   ('976730', 'Halo: The Master Chief Collection'),
#   ('203160', 'Tomb Raider'),
#   ('10180', 'Call of Duty: Modern Warfare 2 (2009)'),
#   ('883710', 'Resident Evil 2'),
#   ('218230', 'PlanetSide 2'),
#   ('333930', 'Dirty Bomb'),
#   ('22380', 'Fallout: New Vegas'),
#   ('1426210', 'It Takes Two'),
#   ('2881650', 'Content Warning'),
#   ('1446780', 'MONSTER HUNTER RISE'),
#   ('387990', 'Scrap Mechanic'),
#   ('582660', 'Black Desert'),
#   ('2694490', 'Path of Exile 2'),
#   ('20', 'Team Fortress Classic'),
#   ('219640', 'Chivalry: Medieval Warfare'),
#   ('30', 'Day of Defeat'),
#   ('1818750', 'MultiVersus'),
#   ('1794680', 'Vampire Survivors'),
#   ('306130', 'The Elder Scrolls Online'),
#   ('225840', 'Sven Co-op'),
#   ('844870', 'KurtzPel'),
#   ('253710', 'theHunter Classic'),
#   ('12210', 'Grand Theft Auto IV: The Complete Edition'),
#   ('273350', 'Evolve Stage 2'),
#   ('1145360', 'Hades'),
#   ('319630', 'Life is Strange - Episode 1'),
#   ('365590', 'Tom Clancy’s The Division'),
#   ('1229490', 'ULTRAKILL'),
#   ('813820', 'Realm Royale'),
#   ('2183900', 'Warhammer 40,000: Space Marine 2'),
#   ('238460', 'BattleBlock Theater'),
#   ('308600', 'Gene Shift Auto'),
#   ('594570', 'Total War: WARHAMMER II'),
#   ('242050', 'Assassin’s Creed IV Black Flag'),
#   ('601150', 'Devil May Cry 5'),
#   ('12120', 'Grand Theft Auto: San Andreas'),
#   ('500', 'Left 4 Dead'),
#   ('8870', 'BioShock Infinite'),
#   ('629760', 'MORDHAU'),
#   ('588650', 'Dead Cells'),
#   ('109600', 'Neverwinter'),
#   ('380', 'Half-Life 2: Episode One'),
#   ('677620', 'Splitgate: Arena Warfare'),
#   ('1118200', 'People Playground'),
#   ('268910', 'Cuphead'),
#   ('1237970', 'Titanfall 2'),
#   ('863550', 'HITMAN 2'),
#   ('273110', 'Counter-Strike Nexon: Studio'),
#   ('555570', 'Infestation: The New Z'),
#   ('10190', 'Call of Duty: Modern Warfare 2 (2009)'),
#   ('868270', 'The Cycle'),
#   ('1593500', 'God of War'),
#   ('782330', 'DOOM Eternal'),
#   ('360', 'Half-Life Deathmatch: Source'),
#   ('548430', 'Deep Rock Galactic'),
#   ('223470', 'POSTAL 2'),
#   ('1551360', 'Forza Horizon 5'),
#   ('232770', 'POSTAL'),
#   ('2630', 'Call of Duty 2'),
#   ('208090', 'Loadout'),
#   ('534380', 'Dying Light 2 Stay Human: Reloaded Edition'),
#   ('48700', 'Mount & Blade: Warband'),
#   ('779340', 'Total War: THREE KINGDOMS'),
#   ('113400', 'APB Reloaded'),
#   ('6060', 'STAR WARS Battlefront II (Classic, 2005)'),
#   ('391220', 'Rise of the Tomb Raider'),
#   ('304390', 'FOR HONOR'),
#   ('206420', 'Saints Row IV: Re-Elected'),
#   ('225540', 'Just Cause 3'),
#   ('386180', 'Crossout'),
#   ('1116170', 'CyberCorp'),
#   ('812140', "Assassin's Creed Odyssey"),
#   ('211820', 'Starbound'),
#   ('200210', 'Realm of the Mad God Exalt'),
#   ('240720', 'Getting Over It with Bennett Foddy'),
#   ('8190', 'Just Cause 2'),
#   ('1144200', 'Ready or Not'),
#   ('42910', 'Magicka'),
#   ('1677740', 'Stumble Guys'),
#   ('1238840', 'Battlefield 1'),
#   ('397540', 'Borderlands 3'),
#   ('1250', 'Killing Floor'),
#   ('238320', 'Outlast'),
#   ('222880', 'Insurgency'),
#   ('115300', 'Call of Duty: Modern Warfare 3 (2011)'),
#   ('1604030', 'V Rising'),
#   ('630', 'Alien Swarm'),
#   ('513710', 'SCUM'),
#   ('744900', 'Dead Frontier 2'),
#   ('244850', 'Space Engineers'),
#   ('355840', 'Survarium'),
#   ('1222680', 'Need for Speed Heat'),
#   ('504370', 'Battlerite'),
#   ('220240', 'Far Cry 3'),
#   ('379720', 'DOOM'),
#   ('1817070', 'Marvel’s Spider-Man Remastered'),
#   ('234140', 'Mad Max'),
#   ('33930', 'Arma 2: Operation Arrowhead'),
#   ('1721470', 'Poppy Playtime'),
#   ('202970', 'Call of Duty: Black Ops II'),
#   ('24240', 'PAYDAY The Heist'),
#   ('871720', 'Ultimate Custom Night'),
#   ('212500', 'The Lord of the Rings Online'),
#   ('1180380', 'Stay Out'),
#   ('304430', 'INSIDE'),
#   ('311690', 'Enter the Gungeon'),
#   ('671860', 'BattleBit Remastered'),
#   ('674940', 'Stick Fight: The Game'),
#   ('205100', 'Dishonored'),
#   ('1145350', 'Hades II'),
#   ('1196590', 'Resident Evil Village'),
#   ('552520', 'Far Cry 5'),
#   ('504230', 'Celeste'),
#   ('546560', 'Half-Life: Alyx'),
#   ('63380', 'Sniper Elite V2'),
#   ('8500', 'EVE Online'),
#   ('7670', 'BioShock'),
#   ('962130', 'Grounded'),
#   ('261640', 'Borderlands: The Pre-Sequel'),
#   ('884660', 'CRSED: F.O.A.D.'),
#   ('48000', 'LIMBO'),
#   ('208650', 'Batman: Arkham Knight'),
#   ('55150', 'Warhammer 40,000: Space Marine - Anniversary Edition'),
#   ('302830', 'BLOCKADE 3D'),
#   ('274190', 'Broforce'),
#   ('389730', 'TEKKEN 7'),
#   ('440900', 'Conan Exiles'),
#   ('312990', 'The Expendabros'),
#   ('376210', 'The Isle'),
#   ('10090', 'Call of Duty: World at War'),
#   ('20900', "The Witcher: Enhanced Edition Director's Cut"),
#   ('1260320', 'Party Animals'),
#   ('265630', 'Fistful of Frags'),
#   ('1222140', 'Detroit: Become Human'),
#   ('1259420', 'Days Gone'),
#   ('356190', 'Middle-earth: Shadow of War'),
#   ('418460', 'Rising Storm 2: Vietnam'),
#   ('552500', 'Warhammer: Vermintide 2'),
#   ('9480', 'Saints Row 2'),
#   ('728880', 'Overcooked! 2'),
#   ('439190', 'Stories: The Path of Destinies'),
#   ('245170', 'Skullgirls 2nd Encore'),
#   ('339610', 'Freestyle 2: Street Basketball'),
#   ('219150', 'Hotline Miami'),
#   ('1057090', 'Ori and the Will of the Wisps'),
#   ('35450', 'Red Orchestra 2: Heroes of Stalingrad with Rising Storm'),
#   ('298110', 'Far Cry 4'),
#   ('424370', 'Wolcen: Lords of Mayhem'),
#   ('881020', 'Granblue Fantasy: Relink'),
#   ('1056960', 'Wolfenstein: Youngblood'),
#   ('232090', 'Killing Floor 2'),
#   ('209080', 'Guns of Icarus Online'),
#   ('918570', 'Century: Age of Ashes'),
#   ('99900', 'Spiral Knights'),
#   ('359320', 'Elite Dangerous'),
#   ('1142710', 'Total War: WARHAMMER III'),
#   ('50', 'Half-Life: Opposing Force'),
#   ('223710', 'Cry of Fear'),
#   ('409710', 'BioShock Remastered'),
#   ('50130', 'Mafia II (Classic)'),
#   ('307780', 'Mortal Kombat X'),
#   ('1203620', 'Enshrouded'),
#   ('285900', 'Gang Beasts'),
#   ('582160', "Assassin's Creed Origins"),
#   ('299360', 'Block N Load'),
#   ('880940', 'Pummel Party'),
#   ('4560', 'Company of Heroes - Legacy Edition'),
#   ('447040', 'Watch_Dogs 2'),
#   ('17410', "Mirror's Edge"),
#   ('362890', 'Black Mesa'),
#   ('233130', 'Shadow Warrior'),
#   ('224600', 'Defiance'),
#   ('379430', 'Kingdom Come: Deliverance'),
#   ('976310', 'Mortal Kombat\xa011'),
#   ('460930', "Tom Clancy's Ghost Recon Wildlands"),
#   ('247080', 'Crypt of the NecroDancer'),
#   ('678950', 'DRAGON BALL FighterZ'),
#   ('287700', 'METAL GEAR SOLID V: THE PHANTOM PAIN'),
#   ('33230', "Assassin's Creed 2"),
#   ('209870', 'Blacklight: Retribution'),
#   ('335300', 'DARK SOULS II: Scholar of the First Sin'),
#   ('274170', 'Hotline Miami 2: Wrong Number'),
#   ('113200', 'The Binding of Isaac'),
#   ('262410', 'World of Guns: Gun Disassembly'),
#   ('1361210', 'Warhammer 40,000: Darktide'),
#   ('418370', 'Resident Evil 7 Biohazard'),
#   ('1942280', 'Brotato'),
#   ('291480', 'Warface'),
#   ('213670', 'South Park: The Stick of Truth'),
#   ('203140', 'Hitman: Absolution'),
#   ('767560', 'War Robots'),
#   ('585690', 'Minimalism'),
#   ('905370', "Conqueror's Blade"),
#   ('12100', 'Grand Theft Auto III'),
#   ('438740', 'Friday the 13th: The Game'),
#   ('214490', 'Alien: Isolation'),
#   ('204880', 'Sins of a Solar Empire: Rebellion'),
#   ('617290', 'Remnant: From the Ashes'),
#   ('289650', "Assassin's Creed Unity"),
#   ('269210', 'Hero Siege'),
#   ('312660', 'Sniper Elite 4'),
#   ('412020', 'Metro Exodus'),
#   ('1371980', 'No Rest for the Wicked'),
#   ('282440', 'Quake Live'),
#   ('686810', 'Hell Let Loose'),
#   ('1056640', 'Phantasy Star Online 2'),
#   ('65800', 'Dungeon Defenders'),
#   ('387290', 'Ori and the Blind Forest: Definitive Edition'),
#   ('646910', 'The Crew 2'),
#   ('233860', 'Kenshi'),
#   ('400', 'Portal'),
#   ('992300', '嗜血印 Bloody Spell'),
#   ('364360', 'Total War: WARHAMMER'),
#   ('235460', 'METAL GEAR RISING: REVENGEANCE'),
#   ('967050', 'Pacify'),
#   ('367500', "Dragon's Dogma: Dark Arisen"),
#   ('286690', 'Metro 2033 Redux'),
#   ('1372880', 'The Day Before'),
#   ('1366800', 'Crosshair X'),
#   ('55230', 'Saints Row: The Third'),
#   ('550900', 'Metin2'),
#   ('287390', 'Metro: Last Light Redux'),
#   ('242720', 'GunZ 2: The Second Duel'),
#   ('407530', 'ARK: Survival Of The Fittest'),
#   ('581320', 'Insurgency: Sandstorm'),
#   ('1172380', 'STAR WARS Jedi: Fallen Order'),
#   ('221040', 'Resident Evil 6'),
#   ('427730', "Who's Your Daddy?!"),
#   ('8850', 'BioShock 2'),
#   ('24200', 'DC Universe Online'),
#   ('248570', 'Toribash'),
#   ('203290', "America's Army: Proving Grounds")],
#  'Adventure': [('578080', 'PUBG: BATTLEGROUNDS'),
#   ('1623730', 'Palworld'),
#   ('1172470', 'Apex Legends'),
#   ('1063730', 'New World: Aeternum'),
#   ('2358720', 'Black Myth: Wukong'),
#   ('271590', 'Grand Theft Auto V Legacy'),
#   ('1599340', 'Lost Ark'),
#   ('304930', 'Unturned'),
#   ('105600', 'Terraria'),
#   ('1086940', "Baldur's Gate 3"),
#   ('1085660', 'Destiny 2'),
#   ('252490', 'Rust'),
#   ('346110', 'ARK: Survival Evolved'),
#   ('892970', 'Valheim'),
#   ('901583', 'Grand Theft Auto IV: Complete Edition'),
#   ('238960', 'Path of Exile'),
#   ('242760', 'The Forest'),
#   ('322330', "Don't Starve Together"),
#   ('1203220', 'NARAKA: BLADEPOINT'),
#   ('899770', 'Last Epoch'),
#   ('444090', 'Paladins'),
#   ('438100', 'VRChat'),
#   ('272060', 'Serena'),
#   ('990080', 'Hogwarts Legacy'),
#   ('620', 'Portal 2'),
#   ('1966720', 'Lethal Company'),
#   ('1517290', 'Battlefield 2042'),
#   ('386360', 'SMITE'),
#   ('648800', 'Raft'),
#   ('1468810', '鬼谷八荒 Tale of Immortal'),
#   ('1174180', 'Red Dead Redemption 2'),
#   ('367520', 'Hollow Knight'),
#   ('477160', 'Human Fall Flat'),
#   ('251570', '7 Days to Die'),
#   ('814380', 'Sekiro: Shadows Die Twice - GOTY Edition'),
#   ('1222670', 'The Sims 4'),
#   ('433850', 'Z1 Battle Royale'),
#   ('219990', 'Grim Dawn'),
#   ('304050', 'Trove'),
#   ('532210', 'Life is Strange 2'),
#   ('1326470', 'Sons Of The Forest'),
#   ('526870', 'Satisfactory'),
#   ('221100', 'DayZ'),
#   ('204360', 'Castle Crashers'),
#   ('96000', 'The Tiny Bang Story'),
#   ('275850', "No Man's Sky"),
#   ('489520', 'Minion Masters'),
#   ('370910', 'Kathy Rain'),
#   ('278360', 'A Story About My Uncle'),
#   ('275390', 'Guacamelee! Super Turbo Championship Edition'),
#   ('311210', 'Call of Duty: Black Ops III'),
#   ('1172620', 'Sea of Thieves: 2025 Edition'),
#   ('2050650', 'Resident Evil 4'),
#   ('203160', 'Tomb Raider'),
#   ('1426210', 'It Takes Two'),
#   ('2881650', 'Content Warning'),
#   ('387990', 'Scrap Mechanic'),
#   ('582660', 'Black Desert'),
#   ('2694490', 'Path of Exile 2'),
#   ('518790', 'theHunter: Call of the Wild'),
#   ('306130', 'The Elder Scrolls Online'),
#   ('363970', 'Clicker Heroes'),
#   ('253710', 'theHunter Classic'),
#   ('12210', 'Grand Theft Auto IV: The Complete Edition'),
#   ('319630', 'Life is Strange - Episode 1'),
#   ('365590', 'Tom Clancy’s The Division'),
#   ('2183900', 'Warhammer 40,000: Space Marine 2'),
#   ('238460', 'BattleBlock Theater'),
#   ('242050', 'Assassin’s Creed IV Black Flag'),
#   ('588650', 'Dead Cells'),
#   ('109600', 'Neverwinter'),
#   ('397900', 'Business Tour - Board Game with Online Multiplayer'),
#   ('435150', 'Divinity: Original Sin 2 - Definitive Edition'),
#   ('1593500', 'God of War'),
#   ('223470', 'POSTAL 2'),
#   ('766570', 'Russian Fishing 4'),
#   ('1332010', 'Stray'),
#   ('1551360', 'Forza Horizon 5'),
#   ('534380', 'Dying Light 2 Stay Human: Reloaded Edition'),
#   ('15700', "Oddworld: Abe's Oddysee"),
#   ('391220', 'Rise of the Tomb Raider'),
#   ('285800', 'Braveland'),
#   ('206420', 'Saints Row IV: Re-Elected'),
#   ('466560', 'Northgard'),
#   ('225540', 'Just Cause 3'),
#   ('1868140', 'DAVE THE DIVER'),
#   ('386180', 'Crossout'),
#   ('1116170', 'CyberCorp'),
#   ('264710', 'Subnautica'),
#   ('812140', "Assassin's Creed Odyssey"),
#   ('252130', 'Divide By Sheep'),
#   ('211820', 'Starbound'),
#   ('200210', 'Realm of the Mad God Exalt'),
#   ('424840', 'Little Nightmares'),
#   ('8190', 'Just Cause 2'),
#   ('1144200', 'Ready or Not'),
#   ('238320', 'Outlast'),
#   ('1604030', 'V Rising'),
#   ('513710', 'SCUM'),
#   ('351940', 'The Descendant'),
#   ('1222680', 'Need for Speed Heat'),
#   ('220240', 'Far Cry 3'),
#   ('1817070', 'Marvel’s Spider-Man Remastered'),
#   ('234140', 'Mad Max'),
#   ('1721470', 'Poppy Playtime'),
#   ('212500', 'The Lord of the Rings Online'),
#   ('304430', 'INSIDE'),
#   ('311690', 'Enter the Gungeon'),
#   ('205100', 'Dishonored'),
#   ('552520', 'Far Cry 5'),
#   ('504230', 'Celeste'),
#   ('546560', 'Half-Life: Alyx'),
#   ('962130', 'Grounded'),
#   ('48000', 'LIMBO'),
#   ('1832640', 'Mirror 2: Project X'),
#   ('208650', 'Batman: Arkham Knight'),
#   ('274190', 'Broforce'),
#   ('440900', 'Conan Exiles'),
#   ('312990', 'The Expendabros'),
#   ('376210', 'The Isle'),
#   ('1222140', 'Detroit: Become Human'),
#   ('1259420', 'Days Gone'),
#   ('356190', 'Middle-earth: Shadow of War'),
#   ('439190', 'Stories: The Path of Destinies'),
#   ('298110', 'Far Cry 4'),
#   ('424370', 'Wolcen: Lords of Mayhem'),
#   ('881020', 'Granblue Fantasy: Relink'),
#   ('207610', 'The Walking Dead'),
#   ('209080', 'Guns of Icarus Online'),
#   ('99900', 'Spiral Knights'),
#   ('359320', 'Elite Dangerous'),
#   ('361420', 'ASTRONEER'),
#   ('223710', 'Cry of Fear'),
#   ('1289310', 'Helltaker'),
#   ('1203620', 'Enshrouded'),
#   ('285900', 'Gang Beasts'),
#   ('582160', "Assassin's Creed Origins"),
#   ('447040', 'Watch_Dogs 2'),
#   ('17410', "Mirror's Edge"),
#   ('362890', 'Black Mesa'),
#   ('233130', 'Shadow Warrior'),
#   ('379430', 'Kingdom Come: Deliverance'),
#   ('460930', "Tom Clancy's Ghost Recon Wildlands"),
#   ('287700', 'METAL GEAR SOLID V: THE PHANTOM PAIN'),
#   ('391720', 'Layers of Fear (2016)'),
#   ('33230', "Assassin's Creed 2"),
#   ('113200', 'The Binding of Isaac'),
#   ('1361210', 'Warhammer 40,000: Darktide'),
#   ('418370', 'Resident Evil 7 Biohazard'),
#   ('213670', 'South Park: The Stick of Truth'),
#   ('838350', '太吾绘卷 The Scroll Of Taiwu'),
#   ('282070', 'This War of Mine'),
#   ('585690', 'Minimalism'),
#   ('617290', 'Remnant: From the Ashes'),
#   ('289650', "Assassin's Creed Unity"),
#   ('269210', 'Hero Siege'),
#   ('312660', 'Sniper Elite 4'),
#   ('1371980', 'No Rest for the Wicked'),
#   ('331470', 'Everlasting Summer'),
#   ('239030', 'Papers, Please'),
#   ('992300', '嗜血印 Bloody Spell'),
#   ('219740', "Don't Starve"),
#   ('967050', 'Pacify'),
#   ('367500', "Dragon's Dogma: Dark Arisen"),
#   ('1372880', 'The Day Before'),
#   ('1366800', 'Crosshair X'),
#   ('2567870', 'Chained Together'),
#   ('845070', 'The Awesome Adventures of Captain Spirit'),
#   ('550900', 'Metin2'),
#   ('407530', 'ARK: Survival Of The Fittest'),
#   ('1172380', 'STAR WARS Jedi: Fallen Order'),
#   ('305620', 'The Long Dark'),
#   ('221040', 'Resident Evil 6'),
#   ('24200', 'DC Universe Online')],
#  'Simulation': [('236390', 'War Thunder'),
#   ('4000', "Garry's Mod"),
#   ('242760', 'The Forest'),
#   ('322330', "Don't Starve Together"),
#   ('413150', 'Stardew Valley'),
#   ('227300', 'Euro Truck Simulator 2'),
#   ('552990', 'World of Warships'),
#   ('438100', 'VRChat'),
#   ('108600', 'Project Zomboid'),
#   ('648800', 'Raft'),
#   ('1468810', '鬼谷八荒 Tale of Immortal'),
#   ('444200', 'World of Tanks Blitz'),
#   ('301520', 'Robocraft'),
#   ('477160', 'Human Fall Flat'),
#   ('251570', '7 Days to Die'),
#   ('1222670', 'The Sims 4'),
#   ('417910', 'Street Warriors Online'),
#   ('261550', 'Mount & Blade II: Bannerlord'),
#   ('107410', 'Arma 3'),
#   ('255710', 'Cities: Skylines'),
#   ('1326470', 'Sons Of The Forest'),
#   ('526870', 'Satisfactory'),
#   ('1089350', 'NBA 2K20'),
#   ('1811260', 'EA SPORTS FIFA 23'),
#   ('394360', 'Hearts of Iron IV'),
#   ('284160', 'BeamNG.drive'),
#   ('1407200', 'World of Tanks'),
#   ('588430', 'Fallout Shelter'),
#   ('387990', 'Scrap Mechanic'),
#   ('582660', 'Black Desert'),
#   ('518790', 'theHunter: Call of the Wild'),
#   ('244210', 'Assetto Corsa'),
#   ('363970', 'Clicker Heroes'),
#   ('236850', 'Europa Universalis IV'),
#   ('253710', 'theHunter Classic'),
#   ('211500', 'RaceRoom Racing Experience'),
#   ('427520', 'Factorio'),
#   ('233450', 'Prison Architect'),
#   ('1118200', 'People Playground'),
#   ('397900', 'Business Tour - Board Game with Online Multiplayer'),
#   ('2195250', 'EA SPORTS FC 24'),
#   ('294100', 'RimWorld'),
#   ('766570', 'Russian Fishing 4'),
#   ('1551360', 'Forza Horizon 5'),
#   ('1100600', 'Football Manager 2020'),
#   ('466560', 'Northgard'),
#   ('1868140', 'DAVE THE DIVER'),
#   ('223750', 'DCS World Steam Edition'),
#   ('380600', 'Fishing Planet'),
#   ('1225330', 'NBA 2K21'),
#   ('508440', 'Totally Accurate Battle Simulator'),
#   ('244850', 'Space Engineers'),
#   ('286160', 'Tabletop Simulator'),
#   ('212680', 'FTL: Faster Than Light'),
#   ('281990', 'Stellaris'),
#   ('1366540', 'Dyson Sphere Program'),
#   ('323190', 'Frostpunk'),
#   ('33930', 'Arma 2: Operation Arrowhead'),
#   ('1506830', 'FIFA 22'),
#   ('457140', 'Oxygen Not Included'),
#   ('613100', 'House Flipper'),
#   ('270880', 'American Truck Simulator'),
#   ('203770', 'Crusader Kings II'),
#   ('440900', 'Conan Exiles'),
#   ('376210', 'The Isle'),
#   ('220200', 'Kerbal Space Program'),
#   ('516750', 'My Summer Car'),
#   ('418460', 'Rising Storm 2: Vietnam'),
#   ('35450', 'Red Orchestra 2: Heroes of Stalingrad with Rising Storm'),
#   ('209080', 'Guns of Icarus Online'),
#   ('359320', 'Elite Dangerous'),
#   ('285900', 'Gang Beasts'),
#   ('1454400', 'Cookie Clicker'),
#   ('262410', 'World of Guns: Gun Disassembly'),
#   ('282070', 'This War of Mine'),
#   ('1158310', 'Crusader Kings III'),
#   ('265930', 'Goat Simulator'),
#   ('204880', 'Sins of a Solar Empire: Rebellion'),
#   ('436150', 'Governor of Poker 3'),
#   ('686810', 'Hell Let Loose'),
#   ('233860', 'Kenshi'),
#   ('2670630', 'Supermarket Simulator'),
#   ('219740', "Don't Starve"),
#   ('1363080', 'Manor Lords'),
#   ('2567870', 'Chained Together'),
#   ('246620', 'Plague Inc: Evolved'),
#   ('703080', 'Planet Zoo'),
#   ('648350', 'Jurassic World Evolution'),
#   ('305620', 'The Long Dark'),
#   ('3097560', "Liar's Bar"),
#   ('105450', 'Age of Empires III (2007)'),
#   ('641990', 'The Escapists 2')],
#  'RPG': [('1623730', 'Palworld'),
#   ('1063730', 'New World: Aeternum'),
#   ('2358720', 'Black Myth: Wukong'),
#   ('1599340', 'Lost Ark'),
#   ('1245620', 'ELDEN RING'),
#   ('105600', 'Terraria'),
#   ('1086940', "Baldur's Gate 3"),
#   ('252490', 'Rust'),
#   ('346110', 'ARK: Survival Evolved'),
#   ('892970', 'Valheim'),
#   ('1091500', 'Cyberpunk 2077'),
#   ('218620', 'PAYDAY 2'),
#   ('238960', 'Path of Exile'),
#   ('322330', "Don't Starve Together"),
#   ('899770', 'Last Epoch'),
#   ('413150', 'Stardew Valley'),
#   ('292030', 'The Witcher 3: Wild Hunt'),
#   ('990080', 'Hogwarts Legacy'),
#   ('108600', 'Project Zomboid'),
#   ('386360', 'SMITE'),
#   ('1468810', '鬼谷八荒 Tale of Immortal'),
#   ('301520', 'Robocraft'),
#   ('239140', 'Dying Light'),
#   ('251570', '7 Days to Die'),
#   ('230410', 'Warframe'),
#   ('219990', 'Grim Dawn'),
#   ('261550', 'Mount & Blade II: Bannerlord'),
#   ('304050', 'Trove'),
#   ('377160', 'Fallout 4'),
#   ('204360', 'Castle Crashers'),
#   ('49520', 'Borderlands 2'),
#   ('489520', 'Minion Masters'),
#   ('489830', 'The Elder Scrolls V: Skyrim Special Edition'),
#   ('72850', 'The Elder Scrolls V: Skyrim'),
#   ('588430', 'Fallout Shelter'),
#   ('22380', 'Fallout: New Vegas'),
#   ('582660', 'Black Desert'),
#   ('2694490', 'Path of Exile 2'),
#   ('1794680', 'Vampire Survivors'),
#   ('306130', 'The Elder Scrolls Online'),
#   ('363970', 'Clicker Heroes'),
#   ('1145360', 'Hades'),
#   ('365590', 'Tom Clancy’s The Division'),
#   ('2183900', 'Warhammer 40,000: Space Marine 2'),
#   ('1286830', 'STAR WARS: The Old Republic'),
#   ('109600', 'Neverwinter'),
#   ('435150', 'Divinity: Original Sin 2 - Definitive Edition'),
#   ('555570', 'Infestation: The New Z'),
#   ('1593500', 'God of War'),
#   ('391540', 'Undertale'),
#   ('766570', 'Russian Fishing 4'),
#   ('534380', 'Dying Light 2 Stay Human: Reloaded Edition'),
#   ('1151340', 'Fallout 76'),
#   ('48700', 'Mount & Blade: Warband'),
#   ('285800', 'Braveland'),
#   ('1868140', 'DAVE THE DIVER'),
#   ('1116170', 'CyberCorp'),
#   ('812140', "Assassin's Creed Odyssey"),
#   ('262060', 'Darkest Dungeon'),
#   ('211820', 'Starbound'),
#   ('200210', 'Realm of the Mad God Exalt'),
#   ('42910', 'Magicka'),
#   ('39210', 'FINAL FANTASY XIV Online'),
#   ('397540', 'Borderlands 3'),
#   ('1716740', 'Starfield'),
#   ('761890', 'Albion Online'),
#   ('744900', 'Dead Frontier 2'),
#   ('20920', 'The Witcher 2: Assassins of Kings Enhanced Edition'),
#   ('355840', 'Survarium'),
#   ('286160', 'Tabletop Simulator'),
#   ('212500', 'The Lord of the Rings Online'),
#   ('1180380', 'Stay Out'),
#   ('1145350', 'Hades II'),
#   ('8500', 'EVE Online'),
#   ('7670', 'BioShock'),
#   ('261640', 'Borderlands: The Pre-Sequel'),
#   ('1832640', 'Mirror 2: Project X'),
#   ('203770', 'Crusader Kings II'),
#   ('440900', 'Conan Exiles'),
#   ('20900', "The Witcher: Enhanced Edition Director's Cut"),
#   ('356190', 'Middle-earth: Shadow of War'),
#   ('552500', 'Warhammer: Vermintide 2'),
#   ('439190', 'Stories: The Path of Destinies'),
#   ('424370', 'Wolcen: Lords of Mayhem'),
#   ('881020', 'Granblue Fantasy: Relink'),
#   ('99900', 'Spiral Knights'),
#   ('359320', 'Elite Dangerous'),
#   ('409710', 'BioShock Remastered'),
#   ('1203620', 'Enshrouded'),
#   ('582160', "Assassin's Creed Origins"),
#   ('224600', 'Defiance'),
#   ('379430', 'Kingdom Come: Deliverance'),
#   ('247080', 'Crypt of the NecroDancer'),
#   ('335300', 'DARK SOULS II: Scholar of the First Sin'),
#   ('113200', 'The Binding of Isaac'),
#   ('1942280', 'Brotato'),
#   ('213670', 'South Park: The Stick of Truth'),
#   ('838350', '太吾绘卷 The Scroll Of Taiwu'),
#   ('1158310', 'Crusader Kings III'),
#   ('617290', 'Remnant: From the Ashes'),
#   ('269210', 'Hero Siege'),
#   ('1371980', 'No Rest for the Wicked'),
#   ('372000', 'Tree of Savior (English Ver.)'),
#   ('1056640', 'Phantasy Star Online 2'),
#   ('65800', 'Dungeon Defenders'),
#   ('233860', 'Kenshi'),
#   ('992300', '嗜血印 Bloody Spell'),
#   ('367500', "Dragon's Dogma: Dark Arisen"),
#   ('550900', 'Metin2'),
#   ('407530', 'ARK: Survival Of The Fittest'),
#   ('24200', 'DC Universe Online')],
#  'Strategy': [('570', 'Dota 2'),
#   ('1086940', "Baldur's Gate 3"),
#   ('322330', "Don't Starve Together"),
#   ('444090', 'Paladins'),
#   ('552990', 'World of Warships'),
#   ('227940', 'Heroes & Generals'),
#   ('386360', 'SMITE'),
#   ('444200', 'World of Tanks Blitz'),
#   ('251570', '7 Days to Die'),
#   ('261550', 'Mount & Blade II: Bannerlord'),
#   ('8930', "Sid Meier's Civilization V"),
#   ('107410', 'Arma 3'),
#   ('255710', 'Cities: Skylines'),
#   ('289070', 'Sid Meier’s Civilization VI'),
#   ('526870', 'Satisfactory'),
#   ('1046930', 'Dota Underlords'),
#   ('489520', 'Minion Masters'),
#   ('394360', 'Hearts of Iron IV'),
#   ('582660', 'Black Desert'),
#   ('363970', 'Clicker Heroes'),
#   ('236850', 'Europa Universalis IV'),
#   ('594570', 'Total War: WARHAMMER II'),
#   ('231430', 'Company of Heroes 2'),
#   ('427520', 'Factorio'),
#   ('268500', 'XCOM 2'),
#   ('646570', 'Slay the Spire'),
#   ('233450', 'Prison Architect'),
#   ('1049590', 'Eternal Return: Black Survival'),
#   ('397900', 'Business Tour - Board Game with Online Multiplayer'),
#   ('435150', 'Divinity: Original Sin 2 - Definitive Edition'),
#   ('294100', 'RimWorld'),
#   ('779340', 'Total War: THREE KINGDOMS'),
#   ('285800', 'Braveland'),
#   ('466560', 'Northgard'),
#   ('262060', 'Darkest Dungeon'),
#   ('960090', 'Bloons TD 6'),
#   ('508440', 'Totally Accurate Battle Simulator'),
#   ('222880', 'Insurgency'),
#   ('221380', 'Age of Empires II (Retired)'),
#   ('244850', 'Space Engineers'),
#   ('286160', 'Tabletop Simulator'),
#   ('212680', 'FTL: Faster Than Light'),
#   ('281990', 'Stellaris'),
#   ('1366540', 'Dyson Sphere Program'),
#   ('323190', 'Frostpunk'),
#   ('33930', 'Arma 2: Operation Arrowhead'),
#   ('3590', 'Plants vs. Zombies GOTY Edition'),
#   ('813780', 'Age of Empires II: Definitive Edition'),
#   ('8500', 'EVE Online'),
#   ('601510', 'Yu-Gi-Oh! Duel Links'),
#   ('201270', 'Total War: SHOGUN 2'),
#   ('203770', 'Crusader Kings II'),
#   ('440900', 'Conan Exiles'),
#   ('418460', 'Rising Storm 2: Vietnam'),
#   ('214950', 'Total War: ROME II - Emperor Edition'),
#   ('359320', 'Elite Dangerous'),
#   ('1142710', 'Total War: WARHAMMER III'),
#   ('299360', 'Block N Load'),
#   ('4560', 'Company of Heroes - Legacy Edition'),
#   ('1454400', 'Cookie Clicker'),
#   ('262410', 'World of Guns: Gun Disassembly'),
#   ('838350', '太吾绘卷 The Scroll Of Taiwu'),
#   ('1158310', 'Crusader Kings III'),
#   ('905370', "Conqueror's Blade"),
#   ('204880', 'Sins of a Solar Empire: Rebellion'),
#   ('34330', 'Total War: SHOGUN 2'),
#   ('686810', 'Hell Let Loose'),
#   ('65800', 'Dungeon Defenders'),
#   ('233860', 'Kenshi'),
#   ('364360', 'Total War: WARHAMMER'),
#   ('967050', 'Pacify'),
#   ('1363080', 'Manor Lords'),
#   ('246620', 'Plague Inc: Evolved'),
#   ('703080', 'Planet Zoo'),
#   ('648350', 'Jurassic World Evolution'),
#   ('407530', 'ARK: Survival Of The Fittest'),
#   ('316010', 'Magic Duels'),
#   ('305620', 'The Long Dark'),
#   ('3097560', "Liar's Bar"),
#   ('105450', 'Age of Empires III (2007)'),
#   ('248570', 'Toribash'),
#   ('641990', 'The Escapists 2')]}

# %% [markdown]
# ### Count the number of games per genre

# %%
genre_game_counts = {}
for genre, games in genre_game_map.items():
  genre_game_counts[genre] = len(games)

genre_game_counts
# Out:
# {'Sports': 21,
#  'Racing': 14,
#  'Massively Multiplayer': 72,
#  'Casual': 57,
#  'Indie': 164,
#  'Action': 322,
#  'Adventure': 174,
#  'Simulation': 92,
#  'RPG': 111,
#  'Strategy': 82}

# %% [markdown]
# ### Calculate number of players per focused genre based on above ratio

# %%
TOTAL_PLAYERS = 50000

total_genre_instances = sum(genre_game_counts.values())

num_players_per_genre = {
    genre: max(1, round((count / total_genre_instances) * TOTAL_PLAYERS))
    for genre, count in genre_game_counts.items()
}

# ensure total players is exactly 50,000
difference = TOTAL_PLAYERS - sum(num_players_per_genre.values())

# sort difference across genres
genres_sorted = sorted(genre_game_counts, key=genre_game_counts.get, reverse=True)

for i in range(abs(difference)):
    index = i % len(genres_sorted)
    num_players_per_genre[genres_sorted[index]] += (1 if difference > 0 else -1)

# ensure each genre has a positive number of players
for genre in num_players_per_genre:
    num_players_per_genre[genre] = max(1, num_players_per_genre[genre])

print("Final number of players per genre:", num_players_per_genre)
print("Total players generated:", sum(num_players_per_genre.values()))
# Out:
# Final number of players per genre: {'Sports': 947, 'Racing': 631, 'Massively Multiplayer': 3246, 'Casual': 2570, 'Indie': 7394, 'Action': 14517, 'Adventure': 7845, 'Simulation': 4148, 'RPG': 5005, 'Strategy': 3697}
# Total players generated: 50000

# %% [markdown]
# ### Generate the synthetic dataset
# Iterate through each genre, generating a dynamic number of players with libraries focused on given genre

# %%
min_games_per_player = 3
max_games_per_player = 10
total_playtime_range = (100, 500)  # min, max total playtime per player

synthetic_players = {}

for genre, game_list in genre_game_map.items():
    num_players = num_players_per_genre[genre]
    game_ids_in_genre = [game[0] for game in game_list if game[0] in all_games_detailed]  # make sure game exists

    for player_id in range(len(synthetic_players), len(synthetic_players) + num_players):
        synthetic_players[player_id] = {"focused_genre": genre, "games": {}}

        # calculate how many games each player will own
        num_games = random.randint(min_games_per_player, max_games_per_player)

        # ensure 70% of a player's games is in their focus genre
        num_genre_games = int(num_games * 0.7)  # 70% of games in focused genre
        num_other_games = num_games - num_genre_games

        owned_genre_games = random.sample(game_ids_in_genre, min(num_genre_games, len(game_ids_in_genre)))
        other_games = random.sample(
            [g_id for g_id in all_games_detailed.keys() if g_id not in owned_genre_games],
            min(num_other_games, len(all_games_detailed) - len(owned_genre_games))
        )

        total_playtime = random.randint(*total_playtime_range)

        genre_playtime = int(total_playtime * 0.95)  # ensure 95% of a player's playtime is in the focus genre
        other_playtime = total_playtime - genre_playtime


        # distribute playtime randomly
        genre_hours = np.random.dirichlet(np.ones(len(owned_genre_games))) * genre_playtime
        other_hours = np.random.dirichlet(np.ones(len(other_games))) * other_playtime if other_games else []

        # store player data
        for game_id, hours in zip(owned_genre_games, genre_hours):
            synthetic_players[player_id]["games"][game_id] = {**all_games_detailed[game_id], "hours": max(1, int(hours))}

        for game_id, hours in zip(other_games, other_hours):
            synthetic_players[player_id]["games"][game_id] = {**all_games_detailed[game_id], "hours": max(1, int(hours))}

# save dataset as json file
with open("synthetic_training_data.json", "w") as f:
    json.dump(synthetic_players, f, indent=4)

print("Synthetic dataset generated successfully!")
# Out:
# Synthetic dataset generated successfully!

# %% [markdown]
# ### Generate a list of owned games and played hours per player to run manual checks

# %%
filepath = "synthetic_training_data.json"

with open(filepath, 'r') as f:
    data = json.load(f)

if data:
    processed_data = {}

    # process each player's data
    for player_id, player_info in data.items():
        processed_data[player_id] = {
            "focused_genre": player_info["focused_genre"],
            "games": []
        }

        # sort games by # of hours played in descending orde)r
        sorted_games = sorted(player_info["games"].items(), key=lambda x: x[1]["hours"], reverse=True)

        for game_id, game_data in sorted_games:
            processed_data[player_id]["games"].append({
                "game_name": game_data["name"],
                "hours_played": game_data["hours"]
            })

    with open("processed_player_data.json", "w") as f:
        json.dump(processed_data, f, indent=4)

    print("Processed data saved to 'processed_player_data.json'")
# Out:
# Processed data saved to 'processed_player_data.json'
